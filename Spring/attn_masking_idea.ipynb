# %%
import numpy as np
import jax
import jax.numpy as jnp
from jax import random, grad, vmap, jit, value_and_grad
from functools import partial
import matplotlib.pyplot as plt
from tqdm import trange

# Import Flax and Optax
from flax import linen as nn
from flax.training import train_state
import optax

# Import attention utilities
from flax.linen.attention import make_causal_mask

# Define the exact solution of the underdamped harmonic oscillator
def oscillator(d, w0, t):
    w = jnp.sqrt(w0 ** 2 - d ** 2)
    phi = jnp.arctan(-d / w)
    A = 1.0 / (2.0 * jnp.cos(phi))
    cos_term = jnp.cos(phi + w * t)
    exp_term = jnp.exp(-d * t)
    x = exp_term * 2 * A * cos_term
    return x

# Define the Transformer model
class TransformerLayer(nn.Module):
    d_model: int
    num_heads: int
    dropout_rate: float = 0.1

    @nn.compact
    def __call__(self, x, *, training: bool = True):
        # Create causal mask
        seq_len = x.shape[1]
        causal_mask = make_causal_mask(
            jnp.ones((x.shape[0], seq_len)), dtype=x.dtype
        )

        # Multi-head self-attention with causal mask
        attn = nn.SelfAttention(
            num_heads=self.num_heads,
            use_bias=True,
            broadcast_dropout=False,
            dropout_rate=self.dropout_rate,
            deterministic=not training,
            dtype=x.dtype,
        )(x, mask=causal_mask)

        # Add & Norm
        x = x + attn
        x = nn.LayerNorm()(x)

        # Feed-forward network
        ff = nn.Dense(self.d_model * 4)(x)
        ff = nn.tanh(ff)
        ff = nn.Dropout(rate=self.dropout_rate)(ff, deterministic=not training)
        ff = nn.Dense(self.d_model)(ff)

        # Add & Norm
        x = x + ff
        x = nn.LayerNorm()(x)
        return x

class TransformerPINN(nn.Module):
    d_model: int
    num_heads: int
    num_layers: int
    dropout_rate: float = 0.1

    @nn.compact
    def __call__(self, t, *, training: bool = True):
        # Input embedding
        x = t.reshape(t.shape[0], -1, 1)
        x = nn.Dense(self.d_model)(x)
        x = nn.tanh(x)

        # Transformer layers
        for _ in range(self.num_layers):
            x = TransformerLayer(
                self.d_model, self.num_heads, self.dropout_rate
            )(x, training=training)

        # Output layer
        x = nn.Dense(1)(x)
        x = x.squeeze(-1)
        return x

def create_train_state(rng, learning_rate, model, params):
    tx = optax.adam(learning_rate)
    return train_state.TrainState.create(
        apply_fn=model.apply,
        params=params,
        tx=tx
    )

def compute_residual_per_t(t_single, x_single, params):
    t_scalar = t_single[0]
    x_scalar = x_single[0]

    def net_single(t_scalar, params):
        t_input = t_scalar.reshape(1, 1)
        x = model.apply({'params': params}, t_input, training=False)
        x_value = x[0, 0]
        return x_value

    # Compute x_t and x_tt
    x_t = grad(lambda t: net_single(t, params))(t_scalar)
    x_tt = grad(lambda t: grad(lambda t_inner: net_single(t_inner, params))(t))(t_scalar)

    # Compute residual
    residual = x_tt + mu * x_t + k * x_scalar

    # Compute gradient of x_tt w.r.t params
    grad_x_tt = grad(lambda params: x_tt)(params)

    # Compute the norm of the gradient
    grad_x_tt_norm = jax.tree_util.tree_reduce(
        lambda x, y: x + jnp.sum(y ** 2), grad_x_tt, initializer=0.0
    )
    grad_x_tt_norm = jnp.sqrt(grad_x_tt_norm)

    return residual, grad_x_tt_norm

def compute_residual(t, x_pred, params):
    # residuals and grad norms are arrays of shape (sequence_length,)
    residuals, grad_norms = vmap(
        compute_residual_per_t, in_axes=(1, 1, None)
    )(t, x_pred, params)
    return residuals, grad_norms

def loss_fn(model, params, t_r, t_data, x_data, rng1, rng2):
    # Forward pass for residual points
    x_pred_r = model.apply({'params': params}, t_r, training=True, rngs={'dropout': rng1})
    (residual, grad_norms) = compute_residual(t_r, x_pred_r, params)
    loss_res = jnp.mean(residual ** 2)
    grad_norm_mean = jnp.mean(grad_norms)

    # Forward pass for data points
    x_pred_data = model.apply({'params': params}, t_data, training=True, rngs={'dropout': rng2})
    loss_data = jnp.mean((x_pred_data - x_data) ** 2)

    # Initial condition loss
    x0_pred = x_pred_data[0, 0]
    def net_single(t0):
        t_input = t0.reshape(1, 1)
        x = model.apply({'params': params}, t_input, training=False)
        x_value = x[0, 0]
        return x_value
    x0_t_pred = grad(net_single)(jnp.array(0.0))
    loss_ic = (x0_pred - 1.0) ** 2 + (x0_t_pred - 0.0) ** 2

    # Total loss
    total_loss = loss_res + 0.0*loss_data + loss_ic

    return total_loss, grad_norm_mean

@jit
def train_step(state, t_r, t_data, x_data, rng):
    params = state.params

    rng1, rng2 = random.split(rng)

    def loss_and_grad(params):
        loss_value, grad_norm_mean = loss_fn(model, params, t_r, t_data, x_data, rng1, rng2)
        return loss_value, grad_norm_mean

    (loss_value, grad_norm_mean), grads = value_and_grad(loss_and_grad, has_aux=True)(params)
    state = state.apply_gradients(grads=grads)
    return state, loss_value, grad_norm_mean

# Constants for the underdamped harmonic oscillator
d = 2.0
w0 = 20.0
mu = 2 * d
k = w0 ** 2

# Generate data
t_r = jnp.linspace(0.0, 1.0, 100).reshape(1, -1)
t_data = jnp.linspace(0.0, 0.5, 25).reshape(1, -1)
x_data = oscillator(d, w0, t_data).reshape(1, -1)

# Initialize model and training state
rng = random.PRNGKey(0)
model = TransformerPINN(d_model=128, num_heads=4, num_layers=2, dropout_rate=0.1)
params = model.init(rng, t_r)['params']
state = create_train_state(rng, learning_rate=1e-3, model=model, params=params)

# Training loop
loss_log = []
nIter = 10000
pbar = trange(nIter)
for it in pbar:
    rng, step_rng = random.split(rng)
    state, loss_value, grad_norm_mean = train_step(state, t_r, t_data, x_data, step_rng)
    if it % 100 == 0:
        loss_log.append(loss_value)
        pbar.set_postfix({'Loss': loss_value, 'GradNorm_x_tt': grad_norm_mean})

# Evaluation
params = state.params
t_test = jnp.linspace(0.0, 2.0, 200).reshape(1, -1)
x_pred = model.apply({'params': params}, t_test, training=False)
x_pred = x_pred.flatten()
t_test_flat = t_test.flatten()
x_exact = oscillator(d, w0, t_test_flat)

# Plot results
plt.figure()
plt.plot(t_test_flat, x_exact, label='Exact Solution')
plt.plot(t_test_flat, x_pred, '--', label='Transformer PINN Prediction')
plt.scatter(t_data.flatten(), x_data.flatten(), color='red', label='Training Data')
plt.legend()
plt.xlabel('Time $t$')
plt.ylabel('Displacement $x(t)$')
plt.title('Under-damped Harmonic Oscillator with Causal Attention')
plt.show()

# Plot training loss
plt.figure()
plt.plot(np.arange(len(loss_log))*100, loss_log)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training Loss')
plt.show()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
# Before training
t0 = jnp.array([[0.0]])  # Shape: (1, 1)
x0_pred = model.apply({'params': params}, t0, training=False)
print("Initial prediction t(0):", x0_pred)
# Out:
# Initial prediction t(0): [[0.9999174]]

# %%
print("t_r shape:", t_r.shape)
print("t_data shape:", t_data.shape)
print("x_data shape:", x_data.shape)
# Out:
# t_r shape: (1, 100)
# t_data shape: (1, 25)
# x_data shape: (1, 25)

# %%
import jax.numpy as jnp
from jax import random
import matplotlib.pyplot as plt

# Seed for reproducibility
key = random.PRNGKey(0)

# 1. Generate a linearly separable dataset
def generate_linearly_separable_data(key, num_samples=100, dim=2):
    key, subkey = random.split(key)
    # Random hyperplane parameters (optimal weights and bias)
    w_star = random.normal(subkey, (dim,))
    b_star = random.normal(subkey)
    
    # Scale w_star and b_star so that the margin gamma = 1
    gamma = jnp.min(jnp.abs(jnp.dot(w_star, w_star) + b_star))
    w_star = w_star / gamma
    b_star = b_star / gamma

    key, subkey = random.split(key)
    # Generate random points
    X = random.normal(subkey, (num_samples, dim))
    # Labels determined by the hyperplane
    y = jnp.sign(jnp.dot(X, w_star) + b_star)
    return X, y, w_star, b_star

X, y, w_star, b_star = generate_linearly_separable_data(key, num_samples=1000, dim=20)

# 2. Initialize the Perceptron parameters
w = jnp.zeros_like(w_star)
b = 1.0

# For tracking purposes
t = 0  # Number of updates
max_iterations = 1000  # To prevent infinite loops in case of errors
R = jnp.max(jnp.linalg.norm(X, axis=1))
norm_w_list = []
wt_wstar_list = []

# 3. Perceptron Learning Algorithm
while t < max_iterations:
    errors = 0
    for i in range(len(X)):
        if y[i] * (jnp.dot(w, X[i]) + b) <= 0:
            # Update rule
            w = w + y[i] * X[i]
            b = b + y[i]
            t += 1
            errors += 1
            
            # Track the norm of w and the inner product with w_star
            norm_w = jnp.linalg.norm(w)
            norm_w_list.append(norm_w)
            wt_wstar = jnp.dot(w, w_star)
            wt_wstar_list.append(wt_wstar)
            
            # Print the key steps corresponding to the proof
            print(f"Update {t}:")
            print(f"  w^T * w_star = {wt_wstar}")
            print(f"  ||w||^2 = {norm_w ** 2}")
            print(f"  Bound on ||w||^2: {t * R ** 2}")
            print(f"  Minimum required w^T * w_star: {t}")
            break  # Go back to the beginning after an update
    if errors == 0:
        print("Perceptron has converged.")
        break

if t == max_iterations:
    print("Reached maximum iterations without convergence.")

# 4. Plotting the increase in alignment and the growth of the weight vector norm
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(wt_wstar_list, label=r'$w_t^\top w^*$')
plt.plot([i for i in range(1, t+1)], label='Number of updates t')
plt.xlabel('Update step')
plt.ylabel(r'$w_t^\top w^*$')
plt.title('Increase in Alignment with $w^*$')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot([nw ** 2 for nw in norm_w_list], label=r'$||w_t||^2$')
plt.plot([i * R ** 2 for i in range(1, t+1)], label=r'Upper bound $t R^2$')
plt.xlabel('Update step')
plt.ylabel(r'$||w_t||^2$')
plt.title('Growth of the Weight Vector Norm')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Update 1:
#   w^T * w_star = -0.028189411386847496
#   ||w||^2 = 16.195280075073242
#   Bound on ||w||^2: 44.102630615234375
#   Minimum required w^T * w_star: 1
# Update 2:
#   w^T * w_star = 0.2931363582611084
#   ||w||^2 = 28.372013092041016
#   Bound on ||w||^2: 88.20526123046875
#   Minimum required w^T * w_star: 2
# Update 3:
#   w^T * w_star = 0.3195192813873291
#   ||w||^2 = 45.266761779785156
#   Bound on ||w||^2: 132.30789184570312
#   Minimum required w^T * w_star: 3
# Update 4:
#   w^T * w_star = 0.41354697942733765
#   ||w||^2 = 49.0037841796875
#   Bound on ||w||^2: 176.4105224609375
#   Minimum required w^T * w_star: 4
# Update 5:
#   w^T * w_star = 0.9777462482452393
#   ||w||^2 = 78.6429443359375
#   Bound on ||w||^2: 220.51315307617188
#   Minimum required w^T * w_star: 5
# Update 6:
#   w^T * w_star = 1.2408562898635864
#   ||w||^2 = 96.3493423461914
#   Bound on ||w||^2: 264.61578369140625
#   Minimum required w^T * w_star: 6
# Update 7:
#   w^T * w_star = 1.3473656177520752
#   ||w||^2 = 112.26011657714844
#   Bound on ||w||^2: 308.7184143066406
#   Minimum required w^T * w_star: 7
# Update 8:
#   w^T * w_star = 1.6842141151428223
#   ||w||^2 = 126.40989685058594
#   Bound on ||w||^2: 352.821044921875
#   Minimum required w^T * w_star: 8
# Update 9:
#   w^T * w_star = 1.9168925285339355
#   ||w||^2 = 144.0164337158203
#   Bound on ||w||^2: 396.9236755371094
#   Minimum required w^T * w_star: 9
# Update 10:
#   w^T * w_star = 1.9016047716140747
#   ||w||^2 = 155.31121826171875
#   Bound on ||w||^2: 441.02630615234375
#   Minimum required w^T * w_star: 10
# Update 11:
#   w^T * w_star = 2.465804100036621
#   ||w||^2 = 186.79736328125
#   Bound on ||w||^2: 485.1289367675781
#   Minimum required w^T * w_star: 11
# Update 12:
#   w^T * w_star = 2.494440793991089
#   ||w||^2 = 214.39610290527344
#   Bound on ||w||^2: 529.2315673828125
#   Minimum required w^T * w_star: 12
# Update 13:
#   w^T * w_star = 2.613507032394409
#   ||w||^2 = 238.3334503173828
#   Bound on ||w||^2: 573.334228515625
#   Minimum required w^T * w_star: 13
# Update 14:
#   w^T * w_star = 2.5519793033599854
#   ||w||^2 = 265.9289855957031
#   Bound on ||w||^2: 617.4368286132812
#   Minimum required w^T * w_star: 14
# Update 15:
#   w^T * w_star = 2.6363179683685303
#   ||w||^2 = 283.5440368652344
#   Bound on ||w||^2: 661.5394287109375
#   Minimum required w^T * w_star: 15
# Update 16:
#   w^T * w_star = 2.620445966720581
#   ||w||^2 = 280.4666748046875
#   Bound on ||w||^2: 705.64208984375
#   Minimum required w^T * w_star: 16
# Update 17:
#   w^T * w_star = 2.6051583290100098
#   ||w||^2 = 292.7160339355469
#   Bound on ||w||^2: 749.7447509765625
#   Minimum required w^T * w_star: 17
# Update 18:
#   w^T * w_star = 2.6910107135772705
#   ||w||^2 = 282.4339904785156
#   Bound on ||w||^2: 793.8473510742188
#   Minimum required w^T * w_star: 18
# Update 19:
#   w^T * w_star = 2.724350929260254
#   ||w||^2 = 291.4941101074219
#   Bound on ||w||^2: 837.949951171875
#   Minimum required w^T * w_star: 19
# Update 20:
#   w^T * w_star = 2.858344554901123
#   ||w||^2 = 299.51788330078125
#   Bound on ||w||^2: 882.0526123046875
#   Minimum required w^T * w_star: 20
# Update 21:
#   w^T * w_star = 3.007208824157715
#   ||w||^2 = 310.7196350097656
#   Bound on ||w||^2: 926.1552734375
#   Minimum required w^T * w_star: 21
# Update 22:
#   w^T * w_star = 2.937504529953003
#   ||w||^2 = 296.89324951171875
#   Bound on ||w||^2: 970.2578735351562
#   Minimum required w^T * w_star: 22
# Update 23:
#   w^T * w_star = 3.0233571529388428
#   ||w||^2 = 305.30291748046875
#   Bound on ||w||^2: 1014.3604736328125
#   Minimum required w^T * w_star: 23
# Update 24:
#   w^T * w_star = 2.953652858734131
#   ||w||^2 = 303.0505065917969
#   Bound on ||w||^2: 1058.463134765625
#   Minimum required w^T * w_star: 24
# Update 25:
#   w^T * w_star = 3.1122984886169434
#   ||w||^2 = 325.3723449707031
#   Bound on ||w||^2: 1102.5657958984375
#   Minimum required w^T * w_star: 25
# Update 26:
#   w^T * w_star = 3.084108829498291
#   ||w||^2 = 336.4864501953125
#   Bound on ||w||^2: 1146.66845703125
#   Minimum required w^T * w_star: 26
# Update 27:
#   w^T * w_star = 3.2181029319763184
#   ||w||^2 = 353.9697265625
#   Bound on ||w||^2: 1190.77099609375
#   Minimum required w^T * w_star: 27
# Update 28:
#   w^T * w_star = 3.202230930328369
#   ||w||^2 = 375.1683349609375
#   Bound on ||w||^2: 1234.8736572265625
#   Minimum required w^T * w_star: 28
# Update 29:
#   w^T * w_star = 3.2914857864379883
#   ||w||^2 = 362.1624755859375
#   Bound on ||w||^2: 1278.976318359375
#   Minimum required w^T * w_star: 29
# Update 30:
#   w^T * w_star = 3.276198387145996
#   ||w||^2 = 371.7266540527344
#   Bound on ||w||^2: 1323.078857421875
#   Minimum required w^T * w_star: 30
# Update 31:
#   w^T * w_star = 3.5393083095550537
#   ||w||^2 = 411.8453674316406
#   Bound on ||w||^2: 1367.1815185546875
#   Minimum required w^T * w_star: 31
# Update 32:
#   w^T * w_star = 3.6455118656158447
#   ||w||^2 = 410.8061218261719
#   Bound on ||w||^2: 1411.2841796875
#   Minimum required w^T * w_star: 32
# Update 33:
#   w^T * w_star = 4.209711074829102
#   ||w||^2 = 452.26751708984375
#   Bound on ||w||^2: 1455.3868408203125
#   Minimum required w^T * w_star: 33
# Update 34:
#   w^T * w_star = 4.140007019042969
#   ||w||^2 = 455.8447570800781
#   Bound on ||w||^2: 1499.489501953125
#   Minimum required w^T * w_star: 34
# Update 35:
#   w^T * w_star = 4.124719619750977
#   ||w||^2 = 468.2294006347656
#   Bound on ||w||^2: 1543.592041015625
#   Minimum required w^T * w_star: 35
# Update 36:
#   w^T * w_star = 4.210571765899658
#   ||w||^2 = 494.2919616699219
#   Bound on ||w||^2: 1587.6947021484375
#   Minimum required w^T * w_star: 36
# Update 37:
#   w^T * w_star = 4.239208221435547
#   ||w||^2 = 508.65704345703125
#   Bound on ||w||^2: 1631.79736328125
#   Minimum required w^T * w_star: 37
# Update 38:
#   w^T * w_star = 4.169504165649414
#   ||w||^2 = 505.7471618652344
#   Bound on ||w||^2: 1675.89990234375
#   Minimum required w^T * w_star: 38
# Update 39:
#   w^T * w_star = 4.112422466278076
#   ||w||^2 = 485.78131103515625
#   Bound on ||w||^2: 1720.0025634765625
#   Minimum required w^T * w_star: 39
# Update 40:
#   w^T * w_star = 4.208522319793701
#   ||w||^2 = 452.7076721191406
#   Bound on ||w||^2: 1764.105224609375
#   Minimum required w^T * w_star: 40
# Update 41:
#   w^T * w_star = 4.151440620422363
#   ||w||^2 = 450.23760986328125
#   Bound on ||w||^2: 1808.2078857421875
#   Minimum required w^T * w_star: 41
# Update 42:
#   w^T * w_star = 4.177823543548584
#   ||w||^2 = 456.400146484375
#   Bound on ||w||^2: 1852.310546875
#   Minimum required w^T * w_star: 42
# Update 43:
#   w^T * w_star = 4.273922920227051
#   ||w||^2 = 430.1842956542969
#   Bound on ||w||^2: 1896.4130859375
#   Minimum required w^T * w_star: 43
# Update 44:
#   w^T * w_star = 4.370022773742676
#   ||w||^2 = 423.95660400390625
#   Bound on ||w||^2: 1940.5157470703125
#   Minimum required w^T * w_star: 44
# Update 45:
#   w^T * w_star = 4.466122150421143
#   ||w||^2 = 437.71685791015625
#   Bound on ||w||^2: 1984.618408203125
#   Minimum required w^T * w_star: 45
# Update 46:
#   w^T * w_star = 4.585188865661621
#   ||w||^2 = 447.8821105957031
#   Bound on ||w||^2: 2028.720947265625
#   Minimum required w^T * w_star: 46
# Update 47:
#   w^T * w_star = 4.613368511199951
#   ||w||^2 = 443.74468994140625
#   Bound on ||w||^2: 2072.82373046875
#   Minimum required w^T * w_star: 47
# Update 48:
#   w^T * w_star = 4.707396030426025
#   ||w||^2 = 472.7244567871094
#   Bound on ||w||^2: 2116.92626953125
#   Minimum required w^T * w_star: 48
# Update 49:
#   w^T * w_star = 4.6503143310546875
#   ||w||^2 = 469.8402404785156
#   Bound on ||w||^2: 2161.02880859375
#   Minimum required w^T * w_star: 49
# Update 50:
#   w^T * w_star = 4.746413707733154
#   ||w||^2 = 473.4405822753906
#   Bound on ||w||^2: 2205.131591796875
#   Minimum required w^T * w_star: 50
# Update 51:
#   w^T * w_star = 4.842513561248779
#   ||w||^2 = 497.0290832519531
#   Bound on ||w||^2: 2249.234130859375
#   Minimum required w^T * w_star: 51
# Update 52:
#   w^T * w_star = 4.868896007537842
#   ||w||^2 = 503.3734436035156
#   Bound on ||w||^2: 2293.3369140625
#   Minimum required w^T * w_star: 52
# Update 53:
#   w^T * w_star = 4.953235149383545
#   ||w||^2 = 531.8037719726562
#   Bound on ||w||^2: 2337.439453125
#   Minimum required w^T * w_star: 53
# Update 54:
#   w^T * w_star = 4.891707420349121
#   ||w||^2 = 544.8160400390625
#   Bound on ||w||^2: 2381.5419921875
#   Minimum required w^T * w_star: 54
# Update 55:
#   w^T * w_star = 4.834625720977783
#   ||w||^2 = 536.8417358398438
#   Bound on ||w||^2: 2425.644775390625
#   Minimum required w^T * w_star: 55
# Update 56:
#   w^T * w_star = 4.964399337768555
#   ||w||^2 = 542.7028198242188
#   Bound on ||w||^2: 2469.747314453125
#   Minimum required w^T * w_star: 56
# Update 57:
#   w^T * w_star = 5.070908546447754
#   ||w||^2 = 538.6073608398438
#   Bound on ||w||^2: 2513.849853515625
#   Minimum required w^T * w_star: 57
# Update 58:
#   w^T * w_star = 5.1567606925964355
#   ||w||^2 = 575.2905883789062
#   Bound on ||w||^2: 2557.95263671875
#   Minimum required w^T * w_star: 58
# Update 59:
#   w^T * w_star = 5.2528605461120605
#   ||w||^2 = 597.6561889648438
#   Bound on ||w||^2: 2602.05517578125
#   Minimum required w^T * w_star: 59
# Update 60:
#   w^T * w_star = 5.281040668487549
#   ||w||^2 = 589.3402709960938
#   Bound on ||w||^2: 2646.15771484375
#   Minimum required w^T * w_star: 60
# Update 61:
#   w^T * w_star = 5.400106906890869
#   ||w||^2 = 592.0550537109375
#   Bound on ||w||^2: 2690.260498046875
#   Minimum required w^T * w_star: 61
# Update 62:
#   w^T * w_star = 5.496205806732178
#   ||w||^2 = 615.1478271484375
#   Bound on ||w||^2: 2734.363037109375
#   Minimum required w^T * w_star: 62
# Update 63:
#   w^T * w_star = 5.4918012619018555
#   ||w||^2 = 599.72265625
#   Bound on ||w||^2: 2778.4658203125
#   Minimum required w^T * w_star: 63
# Update 64:
#   w^T * w_star = 5.904904365539551
#   ||w||^2 = 636.7353515625
#   Bound on ||w||^2: 2822.568359375
#   Minimum required w^T * w_star: 64
# Update 65:
#   w^T * w_star = 6.011891841888428
#   ||w||^2 = 677.2850952148438
#   Bound on ||w||^2: 2866.6708984375
#   Minimum required w^T * w_star: 65
# Update 66:
#   w^T * w_star = 6.038275718688965
#   ||w||^2 = 681.5331420898438
#   Bound on ||w||^2: 2910.773681640625
#   Minimum required w^T * w_star: 66
# Update 67:
#   w^T * w_star = 6.132303237915039
#   ||w||^2 = 707.02587890625
#   Bound on ||w||^2: 2954.876220703125
#   Minimum required w^T * w_star: 67
# Update 68:
#   w^T * w_star = 6.228403091430664
#   ||w||^2 = 724.7510986328125
#   Bound on ||w||^2: 2998.97900390625
#   Minimum required w^T * w_star: 68
# Update 69:
#   w^T * w_star = 6.256582736968994
#   ||w||^2 = 720.5692749023438
#   Bound on ||w||^2: 3043.08154296875
#   Minimum required w^T * w_star: 69
# Update 70:
#   w^T * w_star = 6.3512864112854
#   ||w||^2 = 743.400146484375
#   Bound on ||w||^2: 3087.18408203125
#   Minimum required w^T * w_star: 70
# Update 71:
#   w^T * w_star = 6.5059733390808105
#   ||w||^2 = 774.040283203125
#   Bound on ||w||^2: 3131.286865234375
#   Minimum required w^T * w_star: 71
# Update 72:
#   w^T * w_star = 6.448891639709473
#   ||w||^2 = 773.7550048828125
#   Bound on ||w||^2: 3175.389404296875
#   Minimum required w^T * w_star: 72
# Update 73:
#   w^T * w_star = 6.477528095245361
#   ||w||^2 = 784.7051391601562
#   Bound on ||w||^2: 3219.491943359375
#   Minimum required w^T * w_star: 73
# Update 74:
#   w^T * w_star = 6.462241172790527
#   ||w||^2 = 785.410888671875
#   Bound on ||w||^2: 3263.5947265625
#   Minimum required w^T * w_star: 74
# Update 75:
#   w^T * w_star = 6.5465803146362305
#   ||w||^2 = 811.5087280273438
#   Bound on ||w||^2: 3307.697265625
#   Minimum required w^T * w_star: 75
# Update 76:
#   w^T * w_star = 6.489498615264893
#   ||w||^2 = 803.9204711914062
#   Bound on ||w||^2: 3351.7998046875
#   Minimum required w^T * w_star: 76
# Update 77:
#   w^T * w_star = 6.585597991943359
#   ||w||^2 = 824.0010986328125
#   Bound on ||w||^2: 3395.902587890625
#   Minimum required w^T * w_star: 77
# Update 78:
#   w^T * w_star = 6.692586898803711
#   ||w||^2 = 861.6804809570312
#   Bound on ||w||^2: 3440.005126953125
#   Minimum required w^T * w_star: 78
# Update 79:
#   w^T * w_star = 6.718968868255615
#   ||w||^2 = 860.4854125976562
#   Bound on ||w||^2: 3484.10791015625
#   Minimum required w^T * w_star: 79
# Update 80:
#   w^T * w_star = 6.813673496246338
#   ||w||^2 = 878.5438232421875
#   Bound on ||w||^2: 3528.21044921875
#   Minimum required w^T * w_star: 80
# Update 81:
#   w^T * w_star = 6.909773349761963
#   ||w||^2 = 900.1234741210938
#   Bound on ||w||^2: 3572.31298828125
#   Minimum required w^T * w_star: 81
# Update 82:
#   w^T * w_star = 6.937952995300293
#   ||w||^2 = 899.0270385742188
#   Bound on ||w||^2: 3616.415771484375
#   Minimum required w^T * w_star: 82
# Update 83:
#   w^T * w_star = 6.922080993652344
#   ||w||^2 = 910.5994262695312
#   Bound on ||w||^2: 3660.518310546875
#   Minimum required w^T * w_star: 83
# Update 84:
#   w^T * w_star = 6.893892288208008
#   ||w||^2 = 897.9749755859375
#   Bound on ||w||^2: 3704.62109375
#   Minimum required w^T * w_star: 84
# Update 85:
#   w^T * w_star = 6.989991664886475
#   ||w||^2 = 924.6951293945312
#   Bound on ||w||^2: 3748.7236328125
#   Minimum required w^T * w_star: 85
# Update 86:
#   w^T * w_star = 6.961812973022461
#   ||w||^2 = 911.9406127929688
#   Bound on ||w||^2: 3792.826171875
#   Minimum required w^T * w_star: 86
# Update 87:
#   w^T * w_star = 6.904731273651123
#   ||w||^2 = 899.12841796875
#   Bound on ||w||^2: 3836.928955078125
#   Minimum required w^T * w_star: 87
# Update 88:
#   w^T * w_star = 6.99712610244751
#   ||w||^2 = 912.6431274414062
#   Bound on ||w||^2: 3881.031494140625
#   Minimum required w^T * w_star: 88
# Update 89:
#   w^T * w_star = 6.970008850097656
#   ||w||^2 = 908.6019287109375
#   Bound on ||w||^2: 3925.134033203125
#   Minimum required w^T * w_star: 89
# Update 90:
#   w^T * w_star = 6.996391296386719
#   ||w||^2 = 908.6884155273438
#   Bound on ||w||^2: 3969.23681640625
#   Minimum required w^T * w_star: 90
# Update 91:
#   w^T * w_star = 7.082244396209717
#   ||w||^2 = 945.47216796875
#   Bound on ||w||^2: 4013.33935546875
#   Minimum required w^T * w_star: 91
# Update 92:
#   w^T * w_star = 7.176947593688965
#   ||w||^2 = 963.9354248046875
#   Bound on ||w||^2: 4057.44189453125
#   Minimum required w^T * w_star: 92
# Update 93:
#   w^T * w_star = 7.27304744720459
#   ||w||^2 = 988.4642944335938
#   Bound on ||w||^2: 4101.54443359375
#   Minimum required w^T * w_star: 93
# Update 94:
#   w^T * w_star = 7.30122709274292
#   ||w||^2 = 983.4913940429688
#   Bound on ||w||^2: 4145.6474609375
#   Minimum required w^T * w_star: 94
# Update 95:
#   w^T * w_star = 7.274110794067383
#   ||w||^2 = 975.7376098632812
#   Bound on ||w||^2: 4189.75
#   Minimum required w^T * w_star: 95
# Update 96:
#   w^T * w_star = 7.245932102203369
#   ||w||^2 = 966.8577270507812
#   Bound on ||w||^2: 4233.8525390625
#   Minimum required w^T * w_star: 96
# Update 97:
#   w^T * w_star = 7.338327407836914
#   ||w||^2 = 990.4586791992188
#   Bound on ||w||^2: 4277.955078125
#   Minimum required w^T * w_star: 97
# Update 98:
#   w^T * w_star = 7.418007850646973
#   ||w||^2 = 1013.1310424804688
#   Bound on ||w||^2: 4322.0576171875
#   Minimum required w^T * w_star: 98
# Update 99:
#   w^T * w_star = 7.402719974517822
#   ||w||^2 = 1008.2706909179688
#   Bound on ||w||^2: 4366.16064453125
#   Minimum required w^T * w_star: 99
# Update 100:
#   w^T * w_star = 7.345638275146484
#   ||w||^2 = 1000.4710693359375
#   Bound on ||w||^2: 4410.26318359375
#   Minimum required w^T * w_star: 100
# Update 101:
#   w^T * w_star = 7.441737174987793
#   ||w||^2 = 1021.8490600585938
#   Bound on ||w||^2: 4454.36572265625
#   Minimum required w^T * w_star: 101
# Update 102:
#   w^T * w_star = 7.536441802978516
#   ||w||^2 = 1050.344482421875
#   Bound on ||w||^2: 4498.46826171875
#   Minimum required w^T * w_star: 102
# Update 103:
#   w^T * w_star = 7.508251667022705
#   ||w||^2 = 1048.1473388671875
#   Bound on ||w||^2: 4542.57080078125
#   Minimum required w^T * w_star: 103
# Update 104:
#   w^T * w_star = 7.604351997375488
#   ||w||^2 = 1075.129638671875
#   Bound on ||w||^2: 4586.673828125
#   Minimum required w^T * w_star: 104
# Update 105:
#   w^T * w_star = 7.588479518890381
#   ||w||^2 = 1081.7437744140625
#   Bound on ||w||^2: 4630.7763671875
#   Minimum required w^T * w_star: 105
# Update 106:
#   w^T * w_star = 7.560290336608887
#   ||w||^2 = 1071.09228515625
#   Bound on ||w||^2: 4674.87890625
#   Minimum required w^T * w_star: 106
# Update 107:
#   w^T * w_star = 7.533173084259033
#   ||w||^2 = 1056.078369140625
#   Bound on ||w||^2: 4718.9814453125
#   Minimum required w^T * w_star: 107
# Update 108:
#   w^T * w_star = 7.6278767585754395
#   ||w||^2 = 1084.0631103515625
#   Bound on ||w||^2: 4763.083984375
#   Minimum required w^T * w_star: 108
# Update 109:
#   w^T * w_star = 7.720272064208984
#   ||w||^2 = 1110.8778076171875
#   Bound on ||w||^2: 4807.1865234375
#   Minimum required w^T * w_star: 109
# Update 110:
#   w^T * w_star = 7.746654510498047
#   ||w||^2 = 1115.6497802734375
#   Bound on ||w||^2: 4851.28955078125
#   Minimum required w^T * w_star: 110
# Update 111:
#   w^T * w_star = 7.676950454711914
#   ||w||^2 = 1103.3834228515625
#   Bound on ||w||^2: 4895.39208984375
#   Minimum required w^T * w_star: 111
# Update 112:
#   w^T * w_star = 7.773050308227539
#   ||w||^2 = 1122.7193603515625
#   Bound on ||w||^2: 4939.49462890625
#   Minimum required w^T * w_star: 112
# Update 113:
#   w^T * w_star = 7.745933532714844
#   ||w||^2 = 1113.033935546875
#   Bound on ||w||^2: 4983.59716796875
#   Minimum required w^T * w_star: 113
# Update 114:
#   w^T * w_star = 7.8876118659973145
#   ||w||^2 = 1146.1839599609375
#   Bound on ||w||^2: 5027.69970703125
#   Minimum required w^T * w_star: 114
# Update 115:
#   w^T * w_star = 7.982316017150879
#   ||w||^2 = 1182.084716796875
#   Bound on ||w||^2: 5071.802734375
#   Minimum required w^T * w_star: 115
# Update 116:
#   w^T * w_star = 7.954127311706543
#   ||w||^2 = 1174.572265625
#   Bound on ||w||^2: 5115.9052734375
#   Minimum required w^T * w_star: 116
# Update 117:
#   w^T * w_star = 8.050226211547852
#   ||w||^2 = 1197.169921875
#   Bound on ||w||^2: 5160.0078125
#   Minimum required w^T * w_star: 117
# Update 118:
#   w^T * w_star = 8.142621040344238
#   ||w||^2 = 1229.706298828125
#   Bound on ||w||^2: 5204.1103515625
#   Minimum required w^T * w_star: 118
# Update 119:
#   w^T * w_star = 8.188789367675781
#   ||w||^2 = 1221.3238525390625
#   Bound on ||w||^2: 5248.212890625
#   Minimum required w^T * w_star: 119
# Update 120:
#   w^T * w_star = 8.26846981048584
#   ||w||^2 = 1248.6649169921875
#   Bound on ||w||^2: 5292.3154296875
#   Minimum required w^T * w_star: 120
# Update 121:
#   w^T * w_star = 8.253181457519531
#   ||w||^2 = 1240.3837890625
#   Bound on ||w||^2: 5336.41845703125
#   Minimum required w^T * w_star: 121
# Update 122:
#   w^T * w_star = 8.183477401733398
#   ||w||^2 = 1231.4754638671875
#   Bound on ||w||^2: 5380.52099609375
#   Minimum required w^T * w_star: 122
# Update 123:
#   w^T * w_star = 8.221881866455078
#   ||w||^2 = 1218.01806640625
#   Bound on ||w||^2: 5424.62353515625
#   Minimum required w^T * w_star: 123
# Update 124:
#   w^T * w_star = 8.376569747924805
#   ||w||^2 = 1260.3228759765625
#   Bound on ||w||^2: 5468.72607421875
#   Minimum required w^T * w_star: 124
# Update 125:
#   w^T * w_star = 8.349452018737793
#   ||w||^2 = 1251.728759765625
#   Bound on ||w||^2: 5512.82861328125
#   Minimum required w^T * w_star: 125
# Update 126:
#   w^T * w_star = 8.455963134765625
#   ||w||^2 = 1243.9998779296875
#   Bound on ||w||^2: 5556.931640625
#   Minimum required w^T * w_star: 126
# Update 127:
#   w^T * w_star = 8.535642623901367
#   ||w||^2 = 1281.731689453125
#   Bound on ||w||^2: 5601.0341796875
#   Minimum required w^T * w_star: 127
# Update 128:
#   w^T * w_star = 8.520354270935059
#   ||w||^2 = 1268.194091796875
#   Bound on ||w||^2: 5645.13671875
#   Minimum required w^T * w_star: 128
# Update 129:
#   w^T * w_star = 8.62734317779541
#   ||w||^2 = 1313.3277587890625
#   Bound on ||w||^2: 5689.2392578125
#   Minimum required w^T * w_star: 129
# Update 130:
#   w^T * w_star = 8.723443031311035
#   ||w||^2 = 1346.8880615234375
#   Bound on ||w||^2: 5733.341796875
#   Minimum required w^T * w_star: 130
# Update 131:
#   w^T * w_star = 8.818146705627441
#   ||w||^2 = 1370.18896484375
#   Bound on ||w||^2: 5777.44482421875
#   Minimum required w^T * w_star: 131
# Update 132:
#   w^T * w_star = 8.910541534423828
#   ||w||^2 = 1396.967041015625
#   Bound on ||w||^2: 5821.54736328125
#   Minimum required w^T * w_star: 132
# Update 133:
#   w^T * w_star = 8.840837478637695
#   ||w||^2 = 1392.4671630859375
#   Bound on ||w||^2: 5865.64990234375
#   Minimum required w^T * w_star: 133
# Update 134:
#   w^T * w_star = 8.867219924926758
#   ||w||^2 = 1395.3529052734375
#   Bound on ||w||^2: 5909.75244140625
#   Minimum required w^T * w_star: 134
# Update 135:
#   w^T * w_star = 8.810139656066895
#   ||w||^2 = 1382.8641357421875
#   Bound on ||w||^2: 5953.85498046875
#   Minimum required w^T * w_star: 135
# Update 136:
#   w^T * w_star = 8.906238555908203
#   ||w||^2 = 1409.44677734375
#   Bound on ||w||^2: 5997.9580078125
#   Minimum required w^T * w_star: 136
# Update 137:
#   w^T * w_star = 8.878061294555664
#   ||w||^2 = 1410.9837646484375
#   Bound on ||w||^2: 6042.060546875
#   Minimum required w^T * w_star: 137
# Update 138:
#   w^T * w_star = 8.963912010192871
#   ||w||^2 = 1447.03466796875
#   Bound on ||w||^2: 6086.1630859375
#   Minimum required w^T * w_star: 138
# Update 139:
#   w^T * w_star = 8.902383804321289
#   ||w||^2 = 1440.6612548828125
#   Bound on ||w||^2: 6130.265625
#   Minimum required w^T * w_star: 139
# Update 140:
#   w^T * w_star = 9.032861709594727
#   ||w||^2 = 1476.39404296875
#   Bound on ||w||^2: 6174.3681640625
#   Minimum required w^T * w_star: 140
# Update 141:
#   w^T * w_star = 8.963159561157227
#   ||w||^2 = 1465.6827392578125
#   Bound on ||w||^2: 6218.470703125
#   Minimum required w^T * w_star: 141
# Update 142:
#   w^T * w_star = 9.04612922668457
#   ||w||^2 = 1458.31689453125
#   Bound on ||w||^2: 6262.57373046875
#   Minimum required w^T * w_star: 142
# Update 143:
#   w^T * w_star = 9.142229080200195
#   ||w||^2 = 1490.9068603515625
#   Bound on ||w||^2: 6306.67626953125
#   Minimum required w^T * w_star: 143
# Update 144:
#   w^T * w_star = 9.1151123046875
#   ||w||^2 = 1481.853515625
#   Bound on ||w||^2: 6350.77880859375
#   Minimum required w^T * w_star: 144
# Update 145:
#   w^T * w_star = 9.20750617980957
#   ||w||^2 = 1515.65185546875
#   Bound on ||w||^2: 6394.88134765625
#   Minimum required w^T * w_star: 145
# Update 146:
#   w^T * w_star = 9.23388957977295
#   ||w||^2 = 1514.9954833984375
#   Bound on ||w||^2: 6438.98388671875
#   Minimum required w^T * w_star: 146
# Update 147:
#   w^T * w_star = 9.262068748474121
#   ||w||^2 = 1501.2119140625
#   Bound on ||w||^2: 6483.0869140625
#   Minimum required w^T * w_star: 147
# Update 148:
#   w^T * w_star = 9.347921371459961
#   ||w||^2 = 1548.572509765625
#   Bound on ||w||^2: 6527.189453125
#   Minimum required w^T * w_star: 148
# Update 149:
#   w^T * w_star = 9.278218269348145
#   ||w||^2 = 1531.841552734375
#   Bound on ||w||^2: 6571.2919921875
#   Minimum required w^T * w_star: 149
# Update 150:
#   w^T * w_star = 9.4234619140625
#   ||w||^2 = 1576.4493408203125
#   Bound on ||w||^2: 6615.39453125
#   Minimum required w^T * w_star: 150
# Update 151:
#   w^T * w_star = 9.533732414245605
#   ||w||^2 = 1626.4588623046875
#   Bound on ||w||^2: 6659.4970703125
#   Minimum required w^T * w_star: 151
# Update 152:
#   w^T * w_star = 9.541666030883789
#   ||w||^2 = 1609.044677734375
#   Bound on ||w||^2: 6703.599609375
#   Minimum required w^T * w_star: 152
# Update 153:
#   w^T * w_star = 9.637764930725098
#   ||w||^2 = 1644.2164306640625
#   Bound on ||w||^2: 6747.70263671875
#   Minimum required w^T * w_star: 153
# Update 154:
#   w^T * w_star = 9.610648155212402
#   ||w||^2 = 1635.6304931640625
#   Bound on ||w||^2: 6791.80517578125
#   Minimum required w^T * w_star: 154
# Update 155:
#   w^T * w_star = 9.752326965332031
#   ||w||^2 = 1676.815673828125
#   Bound on ||w||^2: 6835.90771484375
#   Minimum required w^T * w_star: 155
# Update 156:
#   w^T * w_star = 9.85853099822998
#   ||w||^2 = 1685.337646484375
#   Bound on ||w||^2: 6880.01025390625
#   Minimum required w^T * w_star: 156
# Update 157:
#   w^T * w_star = 9.788825988769531
#   ||w||^2 = 1664.3629150390625
#   Bound on ||w||^2: 6924.11279296875
#   Minimum required w^T * w_star: 157
# Update 158:
#   w^T * w_star = 9.88353157043457
#   ||w||^2 = 1703.8597412109375
#   Bound on ||w||^2: 6968.2158203125
#   Minimum required w^T * w_star: 158
# Update 159:
#   w^T * w_star = 9.855351448059082
#   ||w||^2 = 1701.4287109375
#   Bound on ||w||^2: 7012.318359375
#   Minimum required w^T * w_star: 159
# Update 160:
#   w^T * w_star = 9.951451301574707
#   ||w||^2 = 1736.365478515625
#   Bound on ||w||^2: 7056.4208984375
#   Minimum required w^T * w_star: 160
# Update 161:
#   w^T * w_star = 9.923261642456055
#   ||w||^2 = 1721.633544921875
#   Bound on ||w||^2: 7100.5234375
#   Minimum required w^T * w_star: 161
# Update 162:
#   w^T * w_star = 10.017289161682129
#   ||w||^2 = 1761.240478515625
#   Bound on ||w||^2: 7144.6259765625
#   Minimum required w^T * w_star: 162
# Update 163:
#   w^T * w_star = 10.043673515319824
#   ||w||^2 = 1757.5360107421875
#   Bound on ||w||^2: 7188.72900390625
#   Minimum required w^T * w_star: 163
# Update 164:
#   w^T * w_star = 10.139772415161133
#   ||w||^2 = 1795.2869873046875
#   Bound on ||w||^2: 7232.83154296875
#   Minimum required w^T * w_star: 164
# Update 165:
#   w^T * w_star = 10.112655639648438
#   ||w||^2 = 1784.76171875
#   Bound on ||w||^2: 7276.93408203125
#   Minimum required w^T * w_star: 165
# Update 166:
#   w^T * w_star = 10.254334449768066
#   ||w||^2 = 1830.28857421875
#   Bound on ||w||^2: 7321.03662109375
#   Minimum required w^T * w_star: 166
# Update 167:
#   w^T * w_star = 10.346729278564453
#   ||w||^2 = 1850.688232421875
#   Bound on ||w||^2: 7365.13916015625
#   Minimum required w^T * w_star: 167
# Update 168:
#   w^T * w_star = 10.3185396194458
#   ||w||^2 = 1842.4520263671875
#   Bound on ||w||^2: 7409.2421875
#   Minimum required w^T * w_star: 168
# Update 169:
#   w^T * w_star = 10.413244247436523
#   ||w||^2 = 1878.8304443359375
#   Bound on ||w||^2: 7453.3447265625
#   Minimum required w^T * w_star: 169
# Update 170:
#   w^T * w_star = 10.489002227783203
#   ||w||^2 = 1907.869384765625
#   Bound on ||w||^2: 7497.447265625
#   Minimum required w^T * w_star: 170
# Update 171:
#   w^T * w_star = 10.427474975585938
#   ||w||^2 = 1911.420166015625
#   Bound on ||w||^2: 7541.5498046875
#   Minimum required w^T * w_star: 171
# Update 172:
#   w^T * w_star = 10.567608833312988
#   ||w||^2 = 1942.497802734375
#   Bound on ||w||^2: 7585.65234375
#   Minimum required w^T * w_star: 172
# Update 173:
#   w^T * w_star = 10.539430618286133
#   ||w||^2 = 1941.08837890625
#   Bound on ||w||^2: 7629.7548828125
#   Minimum required w^T * w_star: 173
# Update 174:
#   w^T * w_star = 10.625283241271973
#   ||w||^2 = 1982.1085205078125
#   Bound on ||w||^2: 7673.85791015625
#   Minimum required w^T * w_star: 174
# Update 175:
#   w^T * w_star = 10.55557918548584
#   ||w||^2 = 1967.7135009765625
#   Bound on ||w||^2: 7717.96044921875
#   Minimum required w^T * w_star: 175
# Update 176:
#   w^T * w_star = 10.647974014282227
#   ||w||^2 = 2004.276123046875
#   Bound on ||w||^2: 7762.06298828125
#   Minimum required w^T * w_star: 176
# Update 177:
#   w^T * w_star = 10.590892791748047
#   ||w||^2 = 1993.109619140625
#   Bound on ||w||^2: 7806.16552734375
#   Minimum required w^T * w_star: 177
# Update 178:
#   w^T * w_star = 10.575605392456055
#   ||w||^2 = 1990.498046875
#   Bound on ||w||^2: 7850.26806640625
#   Minimum required w^T * w_star: 178
# Update 179:
#   w^T * w_star = 10.671704292297363
#   ||w||^2 = 2018.9774169921875
#   Bound on ||w||^2: 7894.37109375
#   Minimum required w^T * w_star: 179
# Update 180:
#   w^T * w_star = 10.699884414672852
#   ||w||^2 = 2008.08154296875
#   Bound on ||w||^2: 7938.4736328125
#   Minimum required w^T * w_star: 180
# Update 181:
#   w^T * w_star = 10.672767639160156
#   ||w||^2 = 1989.9312744140625
#   Bound on ||w||^2: 7982.576171875
#   Minimum required w^T * w_star: 181
# Update 182:
#   w^T * w_star = 10.699150085449219
#   ||w||^2 = 1980.73583984375
#   Bound on ||w||^2: 8026.6787109375
#   Minimum required w^T * w_star: 182
# Update 183:
#   w^T * w_star = 10.793177604675293
#   ||w||^2 = 2020.24267578125
#   Bound on ||w||^2: 8070.78125
#   Minimum required w^T * w_star: 183
# Update 184:
#   w^T * w_star = 10.889277458190918
#   ||w||^2 = 2053.47265625
#   Bound on ||w||^2: 8114.8837890625
#   Minimum required w^T * w_star: 184
# Update 185:
#   w^T * w_star = 10.968957901000977
#   ||w||^2 = 2088.1240234375
#   Bound on ||w||^2: 8158.98681640625
#   Minimum required w^T * w_star: 185
# Update 186:
#   w^T * w_star = 10.941841125488281
#   ||w||^2 = 2079.9453125
#   Bound on ||w||^2: 8203.0888671875
#   Minimum required w^T * w_star: 186
# Update 187:
#   w^T * w_star = 11.036544799804688
#   ||w||^2 = 2119.9072265625
#   Bound on ||w||^2: 8247.1923828125
#   Minimum required w^T * w_star: 187
# Update 188:
#   w^T * w_star = 11.008366584777832
#   ||w||^2 = 2116.121826171875
#   Bound on ||w||^2: 8291.294921875
#   Minimum required w^T * w_star: 188
# Update 189:
#   w^T * w_star = 11.100760459899902
#   ||w||^2 = 2153.806396484375
#   Bound on ||w||^2: 8335.3974609375
#   Minimum required w^T * w_star: 189
# Update 190:
#   w^T * w_star = 11.10869312286377
#   ||w||^2 = 2141.009033203125
#   Bound on ||w||^2: 8379.5
#   Minimum required w^T * w_star: 190
# Update 191:
#   w^T * w_star = 11.204793930053711
#   ||w||^2 = 2173.384033203125
#   Bound on ||w||^2: 8423.6025390625
#   Minimum required w^T * w_star: 191
# Update 192:
#   w^T * w_star = 11.177677154541016
#   ||w||^2 = 2161.812255859375
#   Bound on ||w||^2: 8467.705078125
#   Minimum required w^T * w_star: 192
# Update 193:
#   w^T * w_star = 11.204059600830078
#   ||w||^2 = 2153.58251953125
#   Bound on ||w||^2: 8511.8076171875
#   Minimum required w^T * w_star: 193
# Update 194:
#   w^T * w_star = 11.279818534851074
#   ||w||^2 = 2182.052734375
#   Bound on ||w||^2: 8555.91015625
#   Minimum required w^T * w_star: 194
# Update 195:
#   w^T * w_star = 11.419952392578125
#   ||w||^2 = 2220.6767578125
#   Bound on ||w||^2: 8600.0126953125
#   Minimum required w^T * w_star: 195
# Update 196:
#   w^T * w_star = 11.44813346862793
#   ||w||^2 = 2203.93359375
#   Bound on ||w||^2: 8644.115234375
#   Minimum required w^T * w_star: 196
# Update 197:
#   w^T * w_star = 11.385637283325195
#   ||w||^2 = 2183.4375
#   Bound on ||w||^2: 8688.2177734375
#   Minimum required w^T * w_star: 197
# Update 198:
#   w^T * w_star = 11.4591064453125
#   ||w||^2 = 2215.327392578125
#   Bound on ||w||^2: 8732.3212890625
#   Minimum required w^T * w_star: 198
# Update 199:
#   w^T * w_star = 11.430927276611328
#   ||w||^2 = 2214.71728515625
#   Bound on ||w||^2: 8776.423828125
#   Minimum required w^T * w_star: 199
# Update 200:
#   w^T * w_star = 11.516780853271484
#   ||w||^2 = 2260.308837890625
#   Bound on ||w||^2: 8820.5263671875
#   Minimum required w^T * w_star: 200
# Update 201:
#   w^T * w_star = 11.447074890136719
#   ||w||^2 = 2243.66455078125
#   Bound on ||w||^2: 8864.62890625
#   Minimum required w^T * w_star: 201
# Update 202:
#   w^T * w_star = 11.431787490844727
#   ||w||^2 = 2236.976806640625
#   Bound on ||w||^2: 8908.7314453125
#   Minimum required w^T * w_star: 202
# Update 203:
#   w^T * w_star = 11.527888298034668
#   ||w||^2 = 2271.06103515625
#   Bound on ||w||^2: 8952.833984375
#   Minimum required w^T * w_star: 203
# Update 204:
#   w^T * w_star = 11.458184242248535
#   ||w||^2 = 2256.15185546875
#   Bound on ||w||^2: 8996.9365234375
#   Minimum required w^T * w_star: 204
# Update 205:
#   w^T * w_star = 11.431066513061523
#   ||w||^2 = 2233.683837890625
#   Bound on ||w||^2: 9041.0390625
#   Minimum required w^T * w_star: 205
# Update 206:
#   w^T * w_star = 11.525771141052246
#   ||w||^2 = 2272.601806640625
#   Bound on ||w||^2: 9085.1416015625
#   Minimum required w^T * w_star: 206
# Update 207:
#   w^T * w_star = 11.618165969848633
#   ||w||^2 = 2307.919677734375
#   Bound on ||w||^2: 9129.244140625
#   Minimum required w^T * w_star: 207
# Update 208:
#   w^T * w_star = 11.75830078125
#   ||w||^2 = 2348.490478515625
#   Bound on ||w||^2: 9173.34765625
#   Minimum required w^T * w_star: 208
# Update 209:
#   w^T * w_star = 11.731184959411621
#   ||w||^2 = 2336.7333984375
#   Bound on ||w||^2: 9217.4501953125
#   Minimum required w^T * w_star: 209
# Update 210:
#   w^T * w_star = 11.81086540222168
#   ||w||^2 = 2378.369384765625
#   Bound on ||w||^2: 9261.552734375
#   Minimum required w^T * w_star: 210
# Update 211:
#   w^T * w_star = 11.795576095581055
#   ||w||^2 = 2367.4404296875
#   Bound on ||w||^2: 9305.6552734375
#   Minimum required w^T * w_star: 211
# Update 212:
#   w^T * w_star = 11.887971878051758
#   ||w||^2 = 2408.326416015625
#   Bound on ||w||^2: 9349.7578125
#   Minimum required w^T * w_star: 212
# Update 213:
#   w^T * w_star = 11.934139251708984
#   ||w||^2 = 2400.149169921875
#   Bound on ||w||^2: 9393.8603515625
#   Minimum required w^T * w_star: 213
# Update 214:
#   w^T * w_star = 12.009897232055664
#   ||w||^2 = 2424.81103515625
#   Bound on ||w||^2: 9437.962890625
#   Minimum required w^T * w_star: 214
# Update 215:
#   w^T * w_star = 11.948369979858398
#   ||w||^2 = 2413.824951171875
#   Bound on ||w||^2: 9482.0654296875
#   Minimum required w^T * w_star: 215
# Update 216:
#   w^T * w_star = 11.907434463500977
#   ||w||^2 = 2395.299072265625
#   Bound on ||w||^2: 9526.16796875
#   Minimum required w^T * w_star: 216
# Update 217:
#   w^T * w_star = 11.980902671813965
#   ||w||^2 = 2436.021728515625
#   Bound on ||w||^2: 9570.2705078125
#   Minimum required w^T * w_star: 217
# Update 218:
#   w^T * w_star = 12.075607299804688
#   ||w||^2 = 2478.72021484375
#   Bound on ||w||^2: 9614.373046875
#   Minimum required w^T * w_star: 218
# Update 219:
#   w^T * w_star = 12.171707153320312
#   ||w||^2 = 2512.712890625
#   Bound on ||w||^2: 9658.4765625
#   Minimum required w^T * w_star: 219
# Update 220:
#   w^T * w_star = 12.102004051208496
#   ||w||^2 = 2500.4482421875
#   Bound on ||w||^2: 9702.5791015625
#   Minimum required w^T * w_star: 220
# Update 221:
#   w^T * w_star = 12.128385543823242
#   ||w||^2 = 2497.38232421875
#   Bound on ||w||^2: 9746.681640625
#   Minimum required w^T * w_star: 221
# Update 222:
#   w^T * w_star = 12.071305274963379
#   ||w||^2 = 2479.360595703125
#   Bound on ||w||^2: 9790.7841796875
#   Minimum required w^T * w_star: 222
# Update 223:
#   w^T * w_star = 12.167403221130371
#   ||w||^2 = 2515.132080078125
#   Bound on ||w||^2: 9834.88671875
#   Minimum required w^T * w_star: 223
# Update 224:
#   w^T * w_star = 12.1392240524292
#   ||w||^2 = 2511.060302734375
#   Bound on ||w||^2: 9878.9892578125
#   Minimum required w^T * w_star: 224
# Update 225:
#   w^T * w_star = 12.225077629089355
#   ||w||^2 = 2558.37060546875
#   Bound on ||w||^2: 9923.091796875
#   Minimum required w^T * w_star: 225
# Update 226:
#   w^T * w_star = 12.197959899902344
#   ||w||^2 = 2537.434326171875
#   Bound on ||w||^2: 9967.1943359375
#   Minimum required w^T * w_star: 226
# Update 227:
#   w^T * w_star = 12.29266357421875
#   ||w||^2 = 2581.7373046875
#   Bound on ||w||^2: 10011.296875
#   Minimum required w^T * w_star: 227
# Update 228:
#   w^T * w_star = 12.385058403015137
#   ||w||^2 = 2620.224609375
#   Bound on ||w||^2: 10055.3994140625
#   Minimum required w^T * w_star: 228
# Update 229:
#   w^T * w_star = 12.356868743896484
#   ||w||^2 = 2606.9609375
#   Bound on ||w||^2: 10099.501953125
#   Minimum required w^T * w_star: 229
# Update 230:
#   w^T * w_star = 12.299284934997559
#   ||w||^2 = 2596.052734375
#   Bound on ||w||^2: 10143.60546875
#   Minimum required w^T * w_star: 230
# Update 231:
#   w^T * w_star = 12.375042915344238
#   ||w||^2 = 2644.59765625
#   Bound on ||w||^2: 10187.7080078125
#   Minimum required w^T * w_star: 231
# Update 232:
#   w^T * w_star = 12.359756469726562
#   ||w||^2 = 2636.260986328125
#   Bound on ||w||^2: 10231.810546875
#   Minimum required w^T * w_star: 232
# Update 233:
#   w^T * w_star = 12.29005241394043
#   ||w||^2 = 2619.10498046875
#   Bound on ||w||^2: 10275.9130859375
#   Minimum required w^T * w_star: 233
# Update 234:
#   w^T * w_star = 12.396256446838379
#   ||w||^2 = 2612.963623046875
#   Bound on ||w||^2: 10320.015625
#   Minimum required w^T * w_star: 234
# Update 235:
#   w^T * w_star = 12.490283966064453
#   ||w||^2 = 2652.478759765625
#   Bound on ||w||^2: 10364.1181640625
#   Minimum required w^T * w_star: 235
# Update 236:
#   w^T * w_star = 12.427786827087402
#   ||w||^2 = 2626.938720703125
#   Bound on ||w||^2: 10408.220703125
#   Minimum required w^T * w_star: 236
# Update 237:
#   w^T * w_star = 12.567922592163086
#   ||w||^2 = 2675.2216796875
#   Bound on ||w||^2: 10452.3232421875
#   Minimum required w^T * w_star: 237
# Update 238:
#   w^T * w_star = 12.688995361328125
#   ||w||^2 = 2719.372314453125
#   Bound on ||w||^2: 10496.42578125
#   Minimum required w^T * w_star: 238
# Update 239:
#   w^T * w_star = 12.764752388000488
#   ||w||^2 = 2759.838134765625
#   Bound on ||w||^2: 10540.5283203125
#   Minimum required w^T * w_star: 239
# Update 240:
#   w^T * w_star = 12.703226089477539
#   ||w||^2 = 2753.07666015625
#   Bound on ||w||^2: 10584.630859375
#   Minimum required w^T * w_star: 240
# Update 241:
#   w^T * w_star = 12.675046920776367
#   ||w||^2 = 2744.232421875
#   Bound on ||w||^2: 10628.734375
#   Minimum required w^T * w_star: 241
# Update 242:
#   w^T * w_star = 12.76089859008789
#   ||w||^2 = 2782.845458984375
#   Bound on ||w||^2: 10672.8369140625
#   Minimum required w^T * w_star: 242
# Update 243:
#   w^T * w_star = 12.733782768249512
#   ||w||^2 = 2766.65478515625
#   Bound on ||w||^2: 10716.939453125
#   Minimum required w^T * w_star: 243
# Update 244:
#   w^T * w_star = 12.760165214538574
#   ||w||^2 = 2752.38720703125
#   Bound on ||w||^2: 10761.0419921875
#   Minimum required w^T * w_star: 244
# Update 245:
#   w^T * w_star = 12.69766902923584
#   ||w||^2 = 2726.835693359375
#   Bound on ||w||^2: 10805.14453125
#   Minimum required w^T * w_star: 245
# Update 246:
#   w^T * w_star = 12.773427963256836
#   ||w||^2 = 2776.765380859375
#   Bound on ||w||^2: 10849.2470703125
#   Minimum required w^T * w_star: 246
# Update 247:
#   w^T * w_star = 12.74524974822998
#   ||w||^2 = 2766.6787109375
#   Bound on ||w||^2: 10893.349609375
#   Minimum required w^T * w_star: 247
# Update 248:
#   w^T * w_star = 12.885385513305664
#   ||w||^2 = 2811.861572265625
#   Bound on ||w||^2: 10937.4521484375
#   Minimum required w^T * w_star: 248
# Update 249:
#   w^T * w_star = 12.822888374328613
#   ||w||^2 = 2782.34033203125
#   Bound on ||w||^2: 10981.5546875
#   Minimum required w^T * w_star: 249
# Update 250:
#   w^T * w_star = 12.943962097167969
#   ||w||^2 = 2830.421875
#   Bound on ||w||^2: 11025.6572265625
#   Minimum required w^T * w_star: 250
# Update 251:
#   w^T * w_star = 13.029812812805176
#   ||w||^2 = 2880.646484375
#   Bound on ||w||^2: 11069.7607421875
#   Minimum required w^T * w_star: 251
# Update 252:
#   w^T * w_star = 13.105571746826172
#   ||w||^2 = 2933.05859375
#   Bound on ||w||^2: 11113.86328125
#   Minimum required w^T * w_star: 252
# Update 253:
#   w^T * w_star = 13.044044494628906
#   ||w||^2 = 2920.83203125
#   Bound on ||w||^2: 11157.9658203125
#   Minimum required w^T * w_star: 253
# Update 254:
#   w^T * w_star = 13.184179306030273
#   ||w||^2 = 2968.885498046875
#   Bound on ||w||^2: 11202.068359375
#   Minimum required w^T * w_star: 254
# Update 255:
#   w^T * w_star = 13.179774284362793
#   ||w||^2 = 2949.0048828125
#   Bound on ||w||^2: 11246.1708984375
#   Minimum required w^T * w_star: 255
# Update 256:
#   w^T * w_star = 13.300847053527832
#   ||w||^2 = 2997.373291015625
#   Bound on ||w||^2: 11290.2734375
#   Minimum required w^T * w_star: 256
# Update 257:
#   w^T * w_star = 13.2633695602417
#   ||w||^2 = 2978.173828125
#   Bound on ||w||^2: 11334.3759765625
#   Minimum required w^T * w_star: 257
# Update 258:
#   w^T * w_star = 13.373639106750488
#   ||w||^2 = 3033.795166015625
#   Bound on ||w||^2: 11378.478515625
#   Minimum required w^T * w_star: 258
# Update 259:
#   w^T * w_star = 13.382465362548828
#   ||w||^2 = 3024.157958984375
#   Bound on ||w||^2: 11422.5810546875
#   Minimum required w^T * w_star: 259
# Update 260:
#   w^T * w_star = 13.462146759033203
#   ||w||^2 = 3058.398681640625
#   Bound on ||w||^2: 11466.68359375
#   Minimum required w^T * w_star: 260
# Update 261:
#   w^T * w_star = 13.399649620056152
#   ||w||^2 = 3038.382568359375
#   Bound on ||w||^2: 11510.7861328125
#   Minimum required w^T * w_star: 261
# Update 262:
#   w^T * w_star = 13.473119735717773
#   ||w||^2 = 3061.615478515625
#   Bound on ||w||^2: 11554.8896484375
#   Minimum required w^T * w_star: 262
# Update 263:
#   w^T * w_star = 13.435641288757324
#   ||w||^2 = 3048.644775390625
#   Bound on ||w||^2: 11598.9921875
#   Minimum required w^T * w_star: 263
# Update 264:
#   w^T * w_star = 13.531739234924316
#   ||w||^2 = 3085.026123046875
#   Bound on ||w||^2: 11643.0947265625
#   Minimum required w^T * w_star: 264
# Update 265:
#   w^T * w_star = 13.503561973571777
#   ||w||^2 = 3080.32958984375
#   Bound on ||w||^2: 11687.197265625
#   Minimum required w^T * w_star: 265
# Update 266:
#   w^T * w_star = 13.579319953918457
#   ||w||^2 = 3127.266845703125
#   Bound on ||w||^2: 11731.2998046875
#   Minimum required w^T * w_star: 266
# Update 267:
#   w^T * w_star = 13.517791748046875
#   ||w||^2 = 3122.064208984375
#   Bound on ||w||^2: 11775.40234375
#   Minimum required w^T * w_star: 267
# Update 268:
#   w^T * w_star = 13.663036346435547
#   ||w||^2 = 3166.827392578125
#   Bound on ||w||^2: 11819.5048828125
#   Minimum required w^T * w_star: 268
# Update 269:
#   w^T * w_star = 13.670970916748047
#   ||w||^2 = 3147.9443359375
#   Bound on ||w||^2: 11863.607421875
#   Minimum required w^T * w_star: 269
# Update 270:
#   w^T * w_star = 13.811105728149414
#   ||w||^2 = 3195.74609375
#   Bound on ||w||^2: 11907.7099609375
#   Minimum required w^T * w_star: 270
# Update 271:
#   w^T * w_star = 13.74860954284668
#   ||w||^2 = 3169.980224609375
#   Bound on ||w||^2: 11951.8125
#   Minimum required w^T * w_star: 271
# Update 272:
#   w^T * w_star = 13.824366569519043
#   ||w||^2 = 3218.38671875
#   Bound on ||w||^2: 11995.916015625
#   Minimum required w^T * w_star: 272
# Update 273:
#   w^T * w_star = 13.796188354492188
#   ||w||^2 = 3212.61865234375
#   Bound on ||w||^2: 12040.0185546875
#   Minimum required w^T * w_star: 273
# Update 274:
#   w^T * w_star = 13.769071578979492
#   ||w||^2 = 3191.60693359375
#   Bound on ||w||^2: 12084.12109375
#   Minimum required w^T * w_star: 274
# Update 275:
#   w^T * w_star = 13.795454978942871
#   ||w||^2 = 3176.999267578125
#   Bound on ||w||^2: 12128.2236328125
#   Minimum required w^T * w_star: 275
# Update 276:
#   w^T * w_star = 13.91652774810791
#   ||w||^2 = 3220.961181640625
#   Bound on ||w||^2: 12172.326171875
#   Minimum required w^T * w_star: 276
# Update 277:
#   w^T * w_star = 14.002379417419434
#   ||w||^2 = 3265.149658203125
#   Bound on ||w||^2: 12216.4287109375
#   Minimum required w^T * w_star: 277
# Update 278:
#   w^T * w_star = 14.075848579406738
#   ||w||^2 = 3307.375
#   Bound on ||w||^2: 12260.53125
#   Minimum required w^T * w_star: 278
# Update 279:
#   w^T * w_star = 14.006146430969238
#   ||w||^2 = 3279.996826171875
#   Bound on ||w||^2: 12304.6337890625
#   Minimum required w^T * w_star: 279
# Update 280:
#   w^T * w_star = 13.99085807800293
#   ||w||^2 = 3265.3017578125
#   Bound on ||w||^2: 12348.736328125
#   Minimum required w^T * w_star: 280
# Update 281:
#   w^T * w_star = 13.921154022216797
#   ||w||^2 = 3244.73779296875
#   Bound on ||w||^2: 12392.8388671875
#   Minimum required w^T * w_star: 281
# Update 282:
#   w^T * w_star = 14.017253875732422
#   ||w||^2 = 3287.265869140625
#   Bound on ||w||^2: 12436.94140625
#   Minimum required w^T * w_star: 282
# Update 283:
#   w^T * w_star = 14.111957550048828
#   ||w||^2 = 3332.098876953125
#   Bound on ||w||^2: 12481.044921875
#   Minimum required w^T * w_star: 283
# Update 284:
#   w^T * w_star = 14.185426712036133
#   ||w||^2 = 3367.365234375
#   Bound on ||w||^2: 12525.1474609375
#   Minimum required w^T * w_star: 284
# Update 285:
#   w^T * w_star = 14.261185646057129
#   ||w||^2 = 3416.854248046875
#   Bound on ||w||^2: 12569.25
#   Minimum required w^T * w_star: 285
# Update 286:
#   w^T * w_star = 14.20410442352295
#   ||w||^2 = 3400.806396484375
#   Bound on ||w||^2: 12613.3525390625
#   Minimum required w^T * w_star: 286
# Update 287:
#   w^T * w_star = 14.175924301147461
#   ||w||^2 = 3390.89599609375
#   Bound on ||w||^2: 12657.455078125
#   Minimum required w^T * w_star: 287
# Update 288:
#   w^T * w_star = 14.272024154663086
#   ||w||^2 = 3431.788330078125
#   Bound on ||w||^2: 12701.5576171875
#   Minimum required w^T * w_star: 288
# Update 289:
#   w^T * w_star = 14.209528923034668
#   ||w||^2 = 3411.832763671875
#   Bound on ||w||^2: 12745.66015625
#   Minimum required w^T * w_star: 289
# Update 290:
#   w^T * w_star = 14.3157320022583
#   ||w||^2 = 3411.75
#   Bound on ||w||^2: 12789.7626953125
#   Minimum required w^T * w_star: 290
# Update 291:
#   w^T * w_star = 14.391490936279297
#   ||w||^2 = 3463.517578125
#   Bound on ||w||^2: 12833.865234375
#   Minimum required w^T * w_star: 291
# Update 292:
#   w^T * w_star = 14.464960098266602
#   ||w||^2 = 3485.637939453125
#   Bound on ||w||^2: 12877.9677734375
#   Minimum required w^T * w_star: 292
# Update 293:
#   w^T * w_star = 14.395256996154785
#   ||w||^2 = 3467.8896484375
#   Bound on ||w||^2: 12922.0703125
#   Minimum required w^T * w_star: 293
# Update 294:
#   w^T * w_star = 14.379968643188477
#   ||w||^2 = 3456.542236328125
#   Bound on ||w||^2: 12966.173828125
#   Minimum required w^T * w_star: 294
# Update 295:
#   w^T * w_star = 14.352851867675781
#   ||w||^2 = 3437.00341796875
#   Bound on ||w||^2: 13010.2763671875
#   Minimum required w^T * w_star: 295
# Update 296:
#   w^T * w_star = 14.447554588317871
#   ||w||^2 = 3481.066162109375
#   Bound on ||w||^2: 13054.37890625
#   Minimum required w^T * w_star: 296
# Update 297:
#   w^T * w_star = 14.527236938476562
#   ||w||^2 = 3526.101318359375
#   Bound on ||w||^2: 13098.4814453125
#   Minimum required w^T * w_star: 297
# Update 298:
#   w^T * w_star = 14.536062240600586
#   ||w||^2 = 3508.6181640625
#   Bound on ||w||^2: 13142.583984375
#   Minimum required w^T * w_star: 298
# Update 299:
#   w^T * w_star = 14.609533309936523
#   ||w||^2 = 3544.34619140625
#   Bound on ||w||^2: 13186.6865234375
#   Minimum required w^T * w_star: 299
# Update 300:
#   w^T * w_star = 14.547037124633789
#   ||w||^2 = 3517.49609375
#   Bound on ||w||^2: 13230.7890625
#   Minimum required w^T * w_star: 300
# Update 301:
#   w^T * w_star = 14.631514549255371
#   ||w||^2 = 3560.685302734375
#   Bound on ||w||^2: 13274.8916015625
#   Minimum required w^T * w_star: 301
# Update 302:
#   w^T * w_star = 14.59057903289795
#   ||w||^2 = 3538.6884765625
#   Bound on ||w||^2: 13318.994140625
#   Minimum required w^T * w_star: 302
# Update 303:
#   w^T * w_star = 14.664047241210938
#   ||w||^2 = 3583.576416015625
#   Bound on ||w||^2: 13363.0966796875
#   Minimum required w^T * w_star: 303
# Update 304:
#   w^T * w_star = 14.594344139099121
#   ||w||^2 = 3565.026123046875
#   Bound on ||w||^2: 13407.19921875
#   Minimum required w^T * w_star: 304
# Update 305:
#   w^T * w_star = 14.69044303894043
#   ||w||^2 = 3605.7109375
#   Bound on ||w||^2: 13451.302734375
#   Minimum required w^T * w_star: 305
# Update 306:
#   w^T * w_star = 14.67515754699707
#   ||w||^2 = 3596.4189453125
#   Bound on ||w||^2: 13495.4052734375
#   Minimum required w^T * w_star: 306
# Update 307:
#   w^T * w_star = 14.613471031188965
#   ||w||^2 = 3552.30029296875
#   Bound on ||w||^2: 13539.5078125
#   Minimum required w^T * w_star: 307
# Update 308:
#   w^T * w_star = 14.693151473999023
#   ||w||^2 = 3598.50048828125
#   Bound on ||w||^2: 13583.6103515625
#   Minimum required w^T * w_star: 308
# Update 309:
#   w^T * w_star = 14.78554630279541
#   ||w||^2 = 3646.276123046875
#   Bound on ||w||^2: 13627.712890625
#   Minimum required w^T * w_star: 309
# Update 310:
#   w^T * w_star = 14.758430480957031
#   ||w||^2 = 3623.5302734375
#   Bound on ||w||^2: 13671.8154296875
#   Minimum required w^T * w_star: 310
# Update 311:
#   w^T * w_star = 14.853133201599121
#   ||w||^2 = 3671.2314453125
#   Bound on ||w||^2: 13715.91796875
#   Minimum required w^T * w_star: 311
# Update 312:
#   w^T * w_star = 14.928892135620117
#   ||w||^2 = 3719.345703125
#   Bound on ||w||^2: 13760.0205078125
#   Minimum required w^T * w_star: 312
# Update 313:
#   w^T * w_star = 14.8663969039917
#   ||w||^2 = 3698.83154296875
#   Bound on ||w||^2: 13804.123046875
#   Minimum required w^T * w_star: 313
# Update 314:
#   w^T * w_star = 15.00653076171875
#   ||w||^2 = 3741.65380859375
#   Bound on ||w||^2: 13848.2255859375
#   Minimum required w^T * w_star: 314
# Update 315:
#   w^T * w_star = 15.007457733154297
#   ||w||^2 = 3740.230712890625
#   Bound on ||w||^2: 13892.3291015625
#   Minimum required w^T * w_star: 315
# Update 316:
#   w^T * w_star = 14.945773124694824
#   ||w||^2 = 3724.959716796875
#   Bound on ||w||^2: 13936.431640625
#   Minimum required w^T * w_star: 316
# Update 317:
#   w^T * w_star = 15.038166046142578
#   ||w||^2 = 3770.2451171875
#   Bound on ||w||^2: 13980.5341796875
#   Minimum required w^T * w_star: 317
# Update 318:
#   w^T * w_star = 14.975671768188477
#   ||w||^2 = 3740.2021484375
#   Bound on ||w||^2: 14024.63671875
#   Minimum required w^T * w_star: 318
# Update 319:
#   w^T * w_star = 15.0615234375
#   ||w||^2 = 3792.79296875
#   Bound on ||w||^2: 14068.7392578125
#   Minimum required w^T * w_star: 319
# Update 320:
#   w^T * w_star = 14.999995231628418
#   ||w||^2 = 3780.114990234375
#   Bound on ||w||^2: 14112.841796875
#   Minimum required w^T * w_star: 320
# Update 321:
#   w^T * w_star = 15.075754165649414
#   ||w||^2 = 3817.225830078125
#   Bound on ||w||^2: 14156.9443359375
#   Minimum required w^T * w_star: 321
# Update 322:
# ...
#   Bound on ||w||^2: 15391.818359375
#   Minimum required w^T * w_star: 349
# Update 350:
#   w^T * w_star = 15.736483573913574
#   ||w||^2 = 4138.89794921875
#   Bound on ||w||^2: 15435.9208984375
#   Minimum required w^T * w_star: 350
# Update 351:
#   w^T * w_star = 15.812241554260254
#   ||w||^2 = 4178.64697265625
#   Bound on ||w||^2: 15480.0234375
#   Minimum required w^T * w_star: 351
# Update 352:
#   w^T * w_star = 15.796954154968262
#   ||w||^2 = 4167.37060546875
#   Bound on ||w||^2: 15524.1259765625
#   Minimum required w^T * w_star: 352
# Update 353:
#   w^T * w_star = 15.734457015991211
#   ||w||^2 = 4130.296875
#   Bound on ||w||^2: 15568.228515625
#   Minimum required w^T * w_star: 353
# Update 354:
#   w^T * w_star = 15.807928085327148
#   ||w||^2 = 4168.306640625
#   Bound on ||w||^2: 15612.3310546875
#   Minimum required w^T * w_star: 354
# Update 355:
#   w^T * w_star = 15.738224029541016
#   ||w||^2 = 4142.7578125
#   Bound on ||w||^2: 15656.43359375
#   Minimum required w^T * w_star: 355
# Update 356:
#   w^T * w_star = 15.747051239013672
#   ||w||^2 = 4125.64892578125
#   Bound on ||w||^2: 15700.5361328125
#   Minimum required w^T * w_star: 356
# Update 357:
#   w^T * w_star = 15.826730728149414
#   ||w||^2 = 4175.09716796875
#   Bound on ||w||^2: 15744.638671875
#   Minimum required w^T * w_star: 357
# Update 358:
#   w^T * w_star = 15.900199890136719
#   ||w||^2 = 4219.26220703125
#   Bound on ||w||^2: 15788.7421875
#   Minimum required w^T * w_star: 358
# Update 359:
#   w^T * w_star = 15.86272144317627
#   ||w||^2 = 4197.79345703125
#   Bound on ||w||^2: 15832.8447265625
#   Minimum required w^T * w_star: 359
# Update 360:
#   w^T * w_star = 15.958822250366211
#   ||w||^2 = 4236.16357421875
#   Bound on ||w||^2: 15876.947265625
#   Minimum required w^T * w_star: 360
# Update 361:
#   w^T * w_star = 15.89632511138916
#   ||w||^2 = 4208.833984375
#   Bound on ||w||^2: 15921.0498046875
#   Minimum required w^T * w_star: 361
# Update 362:
#   w^T * w_star = 15.97208309173584
#   ||w||^2 = 4260.26806640625
#   Bound on ||w||^2: 15965.15234375
#   Minimum required w^T * w_star: 362
# Update 363:
#   w^T * w_star = 15.9439058303833
#   ||w||^2 = 4249.673828125
#   Bound on ||w||^2: 16009.2548828125
#   Minimum required w^T * w_star: 363
# Update 364:
#   w^T * w_star = 16.01737403869629
#   ||w||^2 = 4289.54541015625
#   Bound on ||w||^2: 16053.357421875
#   Minimum required w^T * w_star: 364
# Update 365:
#   w^T * w_star = 16.123577117919922
#   ||w||^2 = 4292.17529296875
#   Bound on ||w||^2: 16097.4599609375
#   Minimum required w^T * w_star: 365
# Update 366:
#   w^T * w_star = 16.06108283996582
#   ||w||^2 = 4260.146484375
#   Bound on ||w||^2: 16141.5625
#   Minimum required w^T * w_star: 366
# Update 367:
#   w^T * w_star = 16.1368408203125
#   ||w||^2 = 4306.9892578125
#   Bound on ||w||^2: 16185.6650390625
#   Minimum required w^T * w_star: 367
# Update 368:
#   w^T * w_star = 16.210309982299805
#   ||w||^2 = 4351.2275390625
#   Bound on ||w||^2: 16229.767578125
#   Minimum required w^T * w_star: 368
# Update 369:
#   w^T * w_star = 16.140605926513672
#   ||w||^2 = 4329.49169921875
#   Bound on ||w||^2: 16273.87109375
#   Minimum required w^T * w_star: 369
# Update 370:
#   w^T * w_star = 16.12531852722168
#   ||w||^2 = 4314.4638671875
#   Bound on ||w||^2: 16317.9736328125
#   Minimum required w^T * w_star: 370
# Update 371:
#   w^T * w_star = 16.221418380737305
#   ||w||^2 = 4360.5341796875
#   Bound on ||w||^2: 16362.076171875
#   Minimum required w^T * w_star: 371
# Update 372:
#   w^T * w_star = 16.164335250854492
#   ||w||^2 = 4333.8232421875
#   Bound on ||w||^2: 16406.177734375
#   Minimum required w^T * w_star: 372
# Update 373:
#   w^T * w_star = 16.25904083251953
#   ||w||^2 = 4370.55224609375
#   Bound on ||w||^2: 16450.28125
#   Minimum required w^T * w_star: 373
# Update 374:
#   w^T * w_star = 16.231924057006836
#   ||w||^2 = 4348.20556640625
#   Bound on ||w||^2: 16494.384765625
#   Minimum required w^T * w_star: 374
# Update 375:
#   w^T * w_star = 16.170238494873047
#   ||w||^2 = 4309.7666015625
#   Bound on ||w||^2: 16538.486328125
#   Minimum required w^T * w_star: 375
# Update 376:
#   w^T * w_star = 16.245996475219727
#   ||w||^2 = 4362.556640625
#   Bound on ||w||^2: 16582.58984375
#   Minimum required w^T * w_star: 376
# Update 377:
#   w^T * w_star = 16.183500289916992
#   ||w||^2 = 4325.8994140625
#   Bound on ||w||^2: 16626.69140625
#   Minimum required w^T * w_star: 377
# Update 378:
#   w^T * w_star = 16.27820587158203
#   ||w||^2 = 4379.484375
#   Bound on ||w||^2: 16670.794921875
#   Minimum required w^T * w_star: 378
# Update 379:
#   w^T * w_star = 16.35167694091797
#   ||w||^2 = 4411.267578125
#   Bound on ||w||^2: 16714.896484375
#   Minimum required w^T * w_star: 379
# Update 380:
#   w^T * w_star = 16.289993286132812
#   ||w||^2 = 4381.2646484375
#   Bound on ||w||^2: 16759.0
#   Minimum required w^T * w_star: 380
# Update 381:
#   w^T * w_star = 16.227497100830078
#   ||w||^2 = 4348.43798828125
#   Bound on ||w||^2: 16803.1015625
#   Minimum required w^T * w_star: 381
# Update 382:
#   w^T * w_star = 16.3133487701416
#   ||w||^2 = 4402.66845703125
#   Bound on ||w||^2: 16847.205078125
#   Minimum required w^T * w_star: 382
# Update 383:
#   w^T * w_star = 16.38910484313965
#   ||w||^2 = 4453.3720703125
#   Bound on ||w||^2: 16891.306640625
#   Minimum required w^T * w_star: 383
# Update 384:
#   w^T * w_star = 16.326610565185547
#   ||w||^2 = 4425.44189453125
#   Bound on ||w||^2: 16935.41015625
#   Minimum required w^T * w_star: 384
# Update 385:
#   w^T * w_star = 16.335437774658203
#   ||w||^2 = 4407.978515625
#   Bound on ||w||^2: 16979.513671875
#   Minimum required w^T * w_star: 385
# Update 386:
#   w^T * w_star = 16.408906936645508
#   ||w||^2 = 4439.7626953125
#   Bound on ||w||^2: 17023.615234375
#   Minimum required w^T * w_star: 386
# Update 387:
#   w^T * w_star = 16.34722137451172
#   ||w||^2 = 4396.865234375
#   Bound on ||w||^2: 17067.71875
#   Minimum required w^T * w_star: 387
# Update 388:
#   w^T * w_star = 16.284727096557617
#   ||w||^2 = 4365.779296875
#   Bound on ||w||^2: 17111.8203125
#   Minimum required w^T * w_star: 388
# Update 389:
#   w^T * w_star = 16.360483169555664
#   ||w||^2 = 4415.2978515625
#   Bound on ||w||^2: 17155.923828125
#   Minimum required w^T * w_star: 389
# Update 390:
#   w^T * w_star = 16.4339542388916
#   ||w||^2 = 4450.56396484375
#   Bound on ||w||^2: 17200.025390625
#   Minimum required w^T * w_star: 390
# Update 391:
#   w^T * w_star = 16.372268676757812
#   ||w||^2 = 4412.24755859375
#   Bound on ||w||^2: 17244.12890625
#   Minimum required w^T * w_star: 391
# Update 392:
#   w^T * w_star = 16.309772491455078
#   ||w||^2 = 4375.662109375
#   Bound on ||w||^2: 17288.23046875
#   Minimum required w^T * w_star: 392
# Update 393:
#   w^T * w_star = 16.38553237915039
#   ||w||^2 = 4431.58935546875
#   Bound on ||w||^2: 17332.333984375
#   Minimum required w^T * w_star: 393
# Update 394:
#   w^T * w_star = 16.459001541137695
#   ||w||^2 = 4470.33642578125
#   Bound on ||w||^2: 17376.435546875
#   Minimum required w^T * w_star: 394
# Update 395:
#   w^T * w_star = 16.389297485351562
#   ||w||^2 = 4444.5263671875
#   Bound on ||w||^2: 17420.5390625
#   Minimum required w^T * w_star: 395
# Update 396:
#   w^T * w_star = 16.5103702545166
#   ||w||^2 = 4499.8115234375
#   Bound on ||w||^2: 17464.642578125
#   Minimum required w^T * w_star: 396
# Update 397:
#   w^T * w_star = 16.49508285522461
#   ||w||^2 = 4482.35498046875
#   Bound on ||w||^2: 17508.744140625
#   Minimum required w^T * w_star: 397
# Update 398:
#   w^T * w_star = 16.457603454589844
#   ||w||^2 = 4458.68994140625
#   Bound on ||w||^2: 17552.84765625
#   Minimum required w^T * w_star: 398
# Update 399:
#   w^T * w_star = 16.531070709228516
#   ||w||^2 = 4504.88671875
#   Bound on ||w||^2: 17596.94921875
#   Minimum required w^T * w_star: 399
# Update 400:
#   w^T * w_star = 16.47348976135254
#   ||w||^2 = 4476.962890625
#   Bound on ||w||^2: 17641.052734375
#   Minimum required w^T * w_star: 400
# Update 401:
#   w^T * w_star = 16.411806106567383
#   ||w||^2 = 4456.19091796875
#   Bound on ||w||^2: 17685.154296875
#   Minimum required w^T * w_star: 401
# Update 402:
#   w^T * w_star = 16.504199981689453
#   ||w||^2 = 4514.3203125
#   Bound on ||w||^2: 17729.2578125
#   Minimum required w^T * w_star: 402
# Update 403:
#   w^T * w_star = 16.44170379638672
#   ||w||^2 = 4479.58935546875
#   Bound on ||w||^2: 17773.359375
#   Minimum required w^T * w_star: 403
# Update 404:
#   w^T * w_star = 16.527555465698242
#   ||w||^2 = 4541.69287109375
#   Bound on ||w||^2: 17817.462890625
#   Minimum required w^T * w_star: 404
# Update 405:
#   w^T * w_star = 16.622262954711914
#   ||w||^2 = 4597.7880859375
#   Bound on ||w||^2: 17861.564453125
#   Minimum required w^T * w_star: 405
# Update 406:
#   w^T * w_star = 16.595144271850586
#   ||w||^2 = 4572.01611328125
#   Bound on ||w||^2: 17905.66796875
#   Minimum required w^T * w_star: 406
# Update 407:
#   w^T * w_star = 16.705413818359375
#   ||w||^2 = 4640.89111328125
#   Bound on ||w||^2: 17949.771484375
#   Minimum required w^T * w_star: 407
# Update 408:
#   w^T * w_star = 16.635709762573242
#   ||w||^2 = 4610.31689453125
#   Bound on ||w||^2: 17993.873046875
#   Minimum required w^T * w_star: 408
# Update 409:
#   w^T * w_star = 16.709178924560547
#   ||w||^2 = 4653.06396484375
#   Bound on ||w||^2: 18037.9765625
#   Minimum required w^T * w_star: 409
# Update 410:
#   w^T * w_star = 16.805278778076172
#   ||w||^2 = 4700.5048828125
#   Bound on ||w||^2: 18082.078125
#   Minimum required w^T * w_star: 410
# Update 411:
#   w^T * w_star = 16.899980545043945
#   ||w||^2 = 4753.470703125
#   Bound on ||w||^2: 18126.181640625
#   Minimum required w^T * w_star: 411
# Update 412:
#   w^T * w_star = 16.838298797607422
#   ||w||^2 = 4728.4375
#   Bound on ||w||^2: 18170.283203125
#   Minimum required w^T * w_star: 412
# Update 413:
#   w^T * w_star = 16.91797637939453
#   ||w||^2 = 4777.69287109375
#   Bound on ||w||^2: 18214.38671875
#   Minimum required w^T * w_star: 413
# Update 414:
#   w^T * w_star = 16.85548210144043
#   ||w||^2 = 4749.6318359375
#   Bound on ||w||^2: 18258.48828125
#   Minimum required w^T * w_star: 414
# Update 415:
#   w^T * w_star = 16.864309310913086
#   ||w||^2 = 4733.064453125
#   Bound on ||w||^2: 18302.591796875
#   Minimum required w^T * w_star: 415
# Update 416:
#   w^T * w_star = 16.940067291259766
#   ||w||^2 = 4772.08154296875
#   Bound on ||w||^2: 18346.6953125
#   Minimum required w^T * w_star: 416
# Update 417:
#   w^T * w_star = 17.01353645324707
#   ||w||^2 = 4804.63818359375
#   Bound on ||w||^2: 18390.796875
#   Minimum required w^T * w_star: 417
# Update 418:
#   w^T * w_star = 16.951040267944336
#   ||w||^2 = 4776.513671875
#   Bound on ||w||^2: 18434.900390625
#   Minimum required w^T * w_star: 418
# Update 419:
#   w^T * w_star = 16.913562774658203
#   ||w||^2 = 4755.85400390625
#   Bound on ||w||^2: 18479.001953125
#   Minimum required w^T * w_star: 419
# Update 420:
#   w^T * w_star = 16.987031936645508
#   ||w||^2 = 4802.86669921875
#   Bound on ||w||^2: 18523.10546875
#   Minimum required w^T * w_star: 420
# Update 421:
#   w^T * w_star = 17.083133697509766
#   ||w||^2 = 4849.5458984375
#   Bound on ||w||^2: 18567.20703125
#   Minimum required w^T * w_star: 421
# Update 422:
#   w^T * w_star = 17.013425827026367
#   ||w||^2 = 4825.2880859375
#   Bound on ||w||^2: 18611.310546875
#   Minimum required w^T * w_star: 422
# Update 423:
#   w^T * w_star = 16.998140335083008
#   ||w||^2 = 4808.6943359375
#   Bound on ||w||^2: 18655.412109375
#   Minimum required w^T * w_star: 423
# Update 424:
#   w^T * w_star = 16.9405574798584
#   ||w||^2 = 4785.37548828125
#   Bound on ||w||^2: 18699.515625
#   Minimum required w^T * w_star: 424
# Update 425:
#   w^T * w_star = 17.016313552856445
#   ||w||^2 = 4848.64990234375
#   Bound on ||w||^2: 18743.6171875
#   Minimum required w^T * w_star: 425
# Update 426:
#   w^T * w_star = 17.12251853942871
#   ||w||^2 = 4845.29833984375
#   Bound on ||w||^2: 18787.720703125
#   Minimum required w^T * w_star: 426
# Update 427:
#   w^T * w_star = 17.09433937072754
#   ||w||^2 = 4827.75927734375
#   Bound on ||w||^2: 18831.82421875
#   Minimum required w^T * w_star: 427
# Update 428:
#   w^T * w_star = 17.031843185424805
#   ||w||^2 = 4791.60302734375
#   Bound on ||w||^2: 18875.92578125
#   Minimum required w^T * w_star: 428
# Update 429:
#   w^T * w_star = 17.107603073120117
#   ||w||^2 = 4859.2646484375
#   Bound on ||w||^2: 18920.029296875
#   Minimum required w^T * w_star: 429
# Update 430:
#   w^T * w_star = 17.04607391357422
#   ||w||^2 = 4840.85009765625
#   Bound on ||w||^2: 18964.130859375
#   Minimum required w^T * w_star: 430
# Update 431:
#   w^T * w_star = 17.140100479125977
#   ||w||^2 = 4897.56689453125
#   Bound on ||w||^2: 19008.234375
#   Minimum required w^T * w_star: 431
# Update 432:
#   w^T * w_star = 17.248004913330078
#   ||w||^2 = 4958.853515625
#   Bound on ||w||^2: 19052.3359375
#   Minimum required w^T * w_star: 432
# Update 433:
#   w^T * w_star = 17.321474075317383
#   ||w||^2 = 5000.1630859375
#   Bound on ||w||^2: 19096.439453125
#   Minimum required w^T * w_star: 433
# Update 434:
#   w^T * w_star = 17.259790420532227
#   ||w||^2 = 4970.17236328125
#   Bound on ||w||^2: 19140.541015625
#   Minimum required w^T * w_star: 434
# Update 435:
#   w^T * w_star = 17.197294235229492
#   ||w||^2 = 4928.24951171875
#   Bound on ||w||^2: 19184.64453125
#   Minimum required w^T * w_star: 435
# Update 436:
#   w^T * w_star = 17.27305030822754
#   ||w||^2 = 4973.6318359375
#   Bound on ||w||^2: 19228.74609375
#   Minimum required w^T * w_star: 436
# Update 437:
#   w^T * w_star = 17.346519470214844
#   ||w||^2 = 5018.421875
#   Bound on ||w||^2: 19272.849609375
#   Minimum required w^T * w_star: 437
# Update 438:
#   w^T * w_star = 17.284025192260742
#   ||w||^2 = 4984.13134765625
#   Bound on ||w||^2: 19316.953125
#   Minimum required w^T * w_star: 438
# Update 439:
#   w^T * w_star = 17.222339630126953
#   ||w||^2 = 4945.59033203125
#   Bound on ||w||^2: 19361.0546875
#   Minimum required w^T * w_star: 439
# Update 440:
#   w^T * w_star = 17.298097610473633
#   ||w||^2 = 4997.37939453125
#   Bound on ||w||^2: 19405.158203125
#   Minimum required w^T * w_star: 440
# Update 441:
#   w^T * w_star = 17.235605239868164
#   ||w||^2 = 4961.2265625
#   Bound on ||w||^2: 19449.259765625
#   Minimum required w^T * w_star: 441
# Update 442:
#   w^T * w_star = 17.309072494506836
#   ||w||^2 = 5005.86376953125
#   Bound on ||w||^2: 19493.36328125
#   Minimum required w^T * w_star: 442
# Update 443:
#   w^T * w_star = 17.40377426147461
#   ||w||^2 = 5061.849609375
#   Bound on ||w||^2: 19537.46484375
#   Minimum required w^T * w_star: 443
# Update 444:
#   w^T * w_star = 17.342092514038086
#   ||w||^2 = 5031.74658203125
#   Bound on ||w||^2: 19581.568359375
#   Minimum required w^T * w_star: 444
# Update 445:
#   w^T * w_star = 17.31497573852539
#   ||w||^2 = 5003.935546875
#   Bound on ||w||^2: 19625.669921875
#   Minimum required w^T * w_star: 445
# Update 446:
#   w^T * w_star = 17.40736961364746
#   ||w||^2 = 5062.04248046875
#   Bound on ||w||^2: 19669.7734375
#   Minimum required w^T * w_star: 446
# Update 447:
#   w^T * w_star = 17.493221282958984
#   ||w||^2 = 5122.716796875
#   Bound on ||w||^2: 19713.875
#   Minimum required w^T * w_star: 447
# Update 448:
#   w^T * w_star = 17.42351722717285
#   ||w||^2 = 5091.66064453125
#   Bound on ||w||^2: 19757.978515625
#   Minimum required w^T * w_star: 448
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 44
#      42 errors = 0
#      43 for i in range(len(X)):
# ---> 44     if y[i] * (jnp.dot(w, X[i]) + b) <= 0:
#      45         # Update rule
#      46         w = w + y[i] * X[i]
#      47         b = b + y[i]
#
# File ~/miniconda3/envs/phd/lib/python3.9/site-packages/jax/_src/array.py:260, in ArrayImpl.__bool__(self)
#     258 def __bool__(self):
#     259   core.check_bool_conversion(self)
# --> 260   return bool(self._value)
#
# File ~/miniconda3/envs/phd/lib/python3.9/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniconda3/envs/phd/lib/python3.9/site-packages/jax/_src/array.py:594, in ArrayImpl._value(self)
#     592 if self._npy_value is None:
#     593   if self.is_fully_replicated:
# --> 594     self._npy_value = self._single_device_array_to_np_array()
#     595     self._npy_value.flags.writeable = False
#     596     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
import jax
import jax.numpy as jnp
from jax import random, jit
import matplotlib.pyplot as plt

# Seed for reproducibility
key = random.PRNGKey(0)

# 1. Define the target function
def f(x):
    return jnp.sin(2 * jnp.pi * x)

# 2. Define the activation function (sigmoid)
def sigmoid(z):
    return 1 / (1 + jnp.exp(-z))

# 3. Neural network approximation
def neural_network(params, x):
    W, b, alpha = params['W'], params['b'], params['alpha']
    hidden_layer = sigmoid(jnp.dot(x, W.T) + b)
    output = jnp.dot(hidden_layer, alpha)
    return output

# 4. Training the neural network
def train_network(key, num_neurons=10, num_epochs=10000, learning_rate=0.01):
    # Initialize parameters
    key, subkey = random.split(key)
    W = random.normal(subkey, (num_neurons, 1))  # Shape: (num_neurons, input_dim)
    b = random.normal(subkey, (num_neurons,))    # Shape: (num_neurons,)
    alpha = random.normal(subkey, (num_neurons,))  # Output weights

    params = {'W': W, 'b': b, 'alpha': alpha}

    # Generate training data
    x = jnp.linspace(0, 1, 100).reshape(-1, 1)
    y_true = f(x).reshape(-1)

    # Training loop
    for epoch in range(num_epochs):
        # Forward pass
        y_pred = neural_network(params, x).reshape(-1)
        loss = jnp.mean((y_pred - y_true) ** 2)

        # Compute gradients
        def loss_fn(params):
            y_pred = neural_network(params, x).reshape(-1)
            return jnp.mean((y_pred - y_true) ** 2)

        grads = jax.grad(loss_fn)(params)

        # Update parameters
        params['W'] = params['W'] - learning_rate * grads['W']
        params['b'] = params['b'] - learning_rate * grads['b']
        params['alpha'] = params['alpha'] - learning_rate * grads['alpha']

        # Optional: Print loss every 1000 epochs
        if epoch % 1000 == 0:
            print(f"Epoch {epoch}, Loss: {loss}")

    return params

# 5. Train the network
trained_params = train_network(key, num_neurons=10000, num_epochs=10000, learning_rate=0.01)

# 6. Plot the results
x_test = jnp.linspace(0, 1, 200).reshape(-1, 1)
y_test = f(x_test)
y_pred = neural_network(trained_params, x_test)

plt.figure(figsize=(8, 6))
plt.plot(x_test, y_test, label='Target Function $f(x) = \sin(2\pi x)$')
plt.plot(x_test, y_pred, label='Neural Network Approximation')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.title('Universal Approximation Theorem Demonstration')
plt.legend()
plt.show()
# Out:
# Epoch 0, Loss: 6802215.5
# Epoch 1000, Loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 63
#      60     return params
#      62 # 5. Train the network
# ---> 63 trained_params = train_network(key, num_neurons=10000, num_epochs=10000, learning_rate=0.01)
#      65 # 6. Plot the results
#      66 x_test = jnp.linspace(0, 1, 200).reshape(-1, 1)
#
# Cell In[15], line 42, in train_network(key, num_neurons, num_epochs, learning_rate)
#      39 for epoch in range(num_epochs):
#      40     # Forward pass
#      41     y_pred = neural_network(params, x).reshape(-1)
# ---> 42     loss = jnp.mean((y_pred - y_true) ** 2)
#      44     # Compute gradients
#      45     def loss_fn(params):
#
# File ~/miniconda3/envs/phd/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py:265, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     263 args = (other, self) if swap else (self, other)
#     264 if isinstance(other, _accepted_binop_types):
# --> 265   return binary_op(*args)
#     266 # Note: don't use isinstance here, because we don't want to raise for
#     267 # subclasses, e.g. NamedTuple objects that may override operators.
#     268 if type(other) in _rejected_binop_types:
#
# KeyboardInterrupt:
