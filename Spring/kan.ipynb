# %% [markdown]
# # Kolmogorov-Arnold State-Space Model
#
# Combining Kolmogorov-Arnold Networks (KANs) with state-space models to improve extrapolation performance is an innovative approach that leverages the strengths of both methodologies. This involves creating a hybrid architecture that combines KANs and state-space models, where the state-space model captures the temporal dynamics and the KAN handles the function approximation.
#
# **State-Space Model (SSM)**: Use a state-space model to describe the evolution of the system's state over time. The state-space model typically consists of:
#
# $$
# \begin{aligned}
# &h_{t+1} = A x_t + B u_t + w_t \\
# &y_t = C x_t + D u_t + v_t
# \end{aligned}
# $$
#
# where $x_t$ is the state vector, $u_t$ is the input vector, $y_t$ is the output vector, and $w_t$ and $v_t$ are noise terms.
#
# **KAN Integration**: Integrate a KAN to approximate the nonlinear functions involved in the state transition or the observation equations. For example, the state transition equation could be modified as:
#
# $$
# h_{t+1} = \sum_{i=1}^{2n+1} \phi_i \left( \sum_{j=1}^n \psi_{ij}(x_t, u_t) \right) + w_t
# $$

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math





class KAN(nn.Module):
    def __init__(
        self,
        layers_hidden,
        grid_size=5,
        spline_order=3,
        scale_noise=0.1,
        scale_base=1.0,
        scale_spline=1.0,
        base_activation=torch.nn.SiLU,
        grid_eps=0.02,
        grid_range=[-1, 1],
    ):
        super(KAN, self).__init__()
        self.grid_size = grid_size
        self.spline_order = spline_order

        self.layers = nn.ModuleList()
        for in_features, out_features in zip(layers_hidden, layers_hidden[1:]):
            self.layers.append(
                KANLinear(
                    in_features,
                    out_features,
                    grid_size=grid_size,
                    spline_order=spline_order,
                    scale_noise=scale_noise,
                    scale_base=scale_base,
                    scale_spline=scale_spline,
                    base_activation=base_activation,
                    grid_eps=grid_eps,
                    grid_range=grid_range,
                )
            )

    def forward(self, x: torch.Tensor, update_grid=False):
        for layer in self.layers:
            if update_grid:
                layer.update_grid(x)
            x = layer(x)
        return x

    def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
        return sum(
            layer.regularization_loss(regularize_activation, regularize_entropy)
            for layer in self.layers
        )

# State-Space Model Implementation
class StateSpaceModel(nn.Module):
    def __init__(self, state_dim, input_dim, output_dim, kan_layers):
        super(StateSpaceModel, self).__init__()
        self.state_dim = state_dim
        self.input_dim = input_dim
        self.output_dim = output_dim

        # Define the KANs for state transition and observation
        self.kan_state_transition = KAN([state_dim + input_dim] + kan_layers + [state_dim])
        self.kan_observation = KAN([state_dim + input_dim] + kan_layers + [output_dim])

    def forward(self, state, input, update_grid=False):
        # State transition: h_{t} = f(h_{t-1}, x_t)
        state_input = torch.cat([state, input], dim=-1)
        next_state = self.kan_state_transition(state_input, update_grid=update_grid)

        # Observation: y_t = g(x_t, u_t)
        observation = self.kan_observation(state_input, update_grid=update_grid)

        return next_state, observation

# Example Usage
state_dim = 1
input_dim = 1
output_dim = 1
kan_layers = [16, 16]

model = StateSpaceModel(state_dim, input_dim, output_dim, kan_layers)

# Example data
batch_size = 1
state = torch.randn(batch_size, state_dim)
input = torch.randn(batch_size, input_dim)
observation_target = torch.randn(batch_size, output_dim)

from torchinfo import summary
print(summary(model, input_data=[state, input]))

# Forward pass
next_state, observation = model(state, input)

# loss
criterion = nn.MSELoss()
loss = criterion(next_state, state) + criterion(observation, observation_target)

print("Next State:", next_state)
print("Observation:", observation)
print("Loss:", loss.item())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 85
#      82 output_dim = 1
#      83 kan_layers = [16, 16]
# ---> 85 model = StateSpaceModel(state_dim, input_dim, output_dim, kan_layers)
#      87 # Example data
#      88 batch_size = 1
#
# Cell In[1], line 66, in StateSpaceModel.__init__(self, state_dim, input_dim, output_dim, kan_layers)
#      63 self.output_dim = output_dim
#      65 # Define the KANs for state transition and observation
# ---> 66 self.kan_state_transition = KAN([state_dim + input_dim] + kan_layers + [state_dim])
#      67 self.kan_observation = KAN([state_dim + input_dim] + kan_layers + [output_dim])
#
# Cell In[1], line 30, in KAN.__init__(self, layers_hidden, grid_size, spline_order, scale_noise, scale_base, scale_spline, base_activation, grid_eps, grid_range)
#      27 self.layers = nn.ModuleList()
#      28 for in_features, out_features in zip(layers_hidden, layers_hidden[1:]):
#      29     self.layers.append(
# ---> 30         KANLinear(
#      31             in_features,
#      32             out_features,
#      33             grid_size=grid_size,
#      34             spline_order=spline_order,
#      35             scale_noise=scale_noise,
#      36             scale_base=scale_base,
#      37             scale_spline=scale_spline,
#      38             base_activation=base_activation,
#      39             grid_eps=grid_eps,
#      40             grid_range=grid_range,
#      41         )
#      42     )
#
# NameError: name 'KANLinear' is not defined

# %% [markdown]
# # Harmonic Oscillator

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Damped harmonic oscillator function
def oscillator(d, w0, t):
    """Defines the analytical solution to the 1D underdamped harmonic oscillator problem."""
    assert d < w0
    d, w0 = torch.Tensor([d]), torch.Tensor([w0])
    w = torch.sqrt(w0**2 - d**2)
    phi = torch.arctan(-d/w)
    A = 1/(2*torch.cos(phi))
    cos = torch.cos(phi + w*t)
    exp = torch.exp(-d*t)
    x = exp * 2 * A * cos
    return x

# Function to generate oscillator data with given parameters
def generate_oscillator_data(seq_length, num_sequences, d, w0, start_time=0):
    t = torch.linspace(start_time, start_time + seq_length//100, seq_length)  # Adjust time scaling as needed
    data = oscillator(d, w0, t).unsqueeze(-1)
    sequences = data.repeat(num_sequences, 1, 1).reshape(num_sequences, seq_length, 1)
    times = t.repeat(num_sequences, 1, 1).reshape(num_sequences, seq_length, 1)
    return sequences, times


# Plotting functions
def plot_loss_curves(train_losses, test_losses, train_seq_length):
    train_losses = np.array(train_losses)
    test_losses = np.array(test_losses)
    
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(test_losses, label="Test Loss")
    plt.yscale('log')
    plt.title(f"Loss Curves for Train Seq Length {train_seq_length}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss (Log Scale)")
    plt.legend()
    plt.show()

# %%
# Parameters
state_dim = 1
input_dim = 1
output_dim = 1
kan_layers = [64, 64]
batch_size = 1
num_sequences = 1
total_seq_length = 240
train_seq_lengths = [5, 10, 15, 20, 30, 60, 90, 120]  # Different lengths of training sequences

convergence_std_threshold = 1e-6  # Standard deviation threshold
patience_counter = 0
patience = 13  # Number of epochs with no improvement to wait before stopping
n_pts = 100


d, w0 = 4, 40

# Initialize performance data dictionary
performance_data = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for train_seq_length in train_seq_lengths:

    test_seq_length = total_seq_length - train_seq_length
    
    model = StateSpaceModel(state_dim, input_dim, output_dim, kan_layers).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.MSELoss()
    
    # Generate data
    total_data, total_times = generate_oscillator_data(total_seq_length, num_sequences, d, w0, start_time=0)
    total_data, total_times = total_data.to(device), total_times.to(device)
    
    # Split into train and test sets by non-overlapping time intervals
    train_data = total_data[:, :train_seq_length, :]
    train_times = total_times[:, :train_seq_length, :]
    test_data = total_data[:, train_seq_length:, :]
    test_times = total_times[:, train_seq_length:, :]
    

    train_losses = []
    test_losses = []
    best_loss = float('inf')
    patience_counter = 0
    
    epoch = 0
    while patience_counter < patience:
        model.train()
        optimizer.zero_grad()
        

        state = train_data # Training part of the sequence
        input = train_times  # Training part of the sequence (next state)
        observation_target = train_data
        
        state = state.reshape(-1, state_dim)
        input = input.reshape(-1, input_dim)
        observation_target = observation_target.reshape(-1, output_dim)
        
        next_state, observation = model(state, input)
        loss = criterion(next_state, state) + criterion(observation, observation_target)
        
        loss.backward()
        optimizer.step()
        
        train_losses.append(loss.item())

        # Check convergence criteria based on the standard deviation of the last few training losses
        if len(train_losses) > n_pts:
            recent_losses = train_losses[-n_pts:]
            std_recent_losses = np.std(recent_losses)
            if std_recent_losses < convergence_std_threshold:
                patience_counter += 1
            else:
                patience_counter = 0
        else:
            patience_counter = 0
        
        # Validation on test data
        model.eval()
        with torch.no_grad():
            # test_state = test_data[:, :train_seq_length-1, :]
            # test_input = test_times[:, 1:train_seq_length, :]

            test_state = test_data
            test_input = test_times
            
            test_state = test_state.reshape(-1, state_dim)
            test_input = test_input.reshape(-1, input_dim)
            
            _, test_observation = model(test_state, test_input)
            
            test_loss = criterion(test_observation, test_data.reshape(-1, output_dim))
            test_losses.append(test_loss.item())

        # if (epoch + 1) % 10 == 0:
        #     print(f"Train Seq Length {train_seq_length}, Epoch {epoch+1}, Train Loss: {loss.item():.3e}, Test Loss: {test_loss.item():.3e}")
        
        epoch += 1
    
    # Save performance data
    performance_data.append({
        "train_seq_length": train_seq_length,
        "final_train_loss": train_losses[-1],
        "final_test_loss": test_losses[-1]
    })
    
    # Plot loss curves
    plot_loss_curves(train_losses, test_losses, train_seq_length)

    
    plt.figure(figsize=(12, 6))
    trn_time_plt = train_times.reshape(-1, 1).cpu().numpy()
    tst_time_plt = test_times.reshape(-1, 1).cpu().numpy()

    trn_true_plt = train_data.reshape(-1, 1).cpu().numpy()
    tst_true_plt = test_data.reshape(-1, 1).cpu().numpy()

    trn_pred_plt = observation.reshape(-1, 1).detach().cpu().numpy()
    tst_pred_plt = test_observation.reshape(-1, 1).detach().cpu().numpy()

    vline = (trn_time_plt[-1]+tst_time_plt[0])/2

    plt.plot(trn_time_plt, trn_true_plt, color='black', linestyle='-', label="True")
    plt.plot(tst_time_plt, tst_true_plt, color='black', linestyle='-')

    plt.plot(trn_time_plt, trn_pred_plt, color='red', linestyle='--', label="Pred")
    plt.plot(tst_time_plt, tst_pred_plt, color='red', linestyle='--')

    plt.axvspan(0, vline[0], alpha=0.3, color='blue', label="Training Data")
    plt.axvspan(vline[0], tst_time_plt[-1][0], alpha=0.3, color='green', label="Testing Data")
    plt.axvline(vline, color='teal', linestyle='--')

    plt.legend()
    plt.show()

# Convert performance data to a DataFrame for seaborn plotting
performance_df = pd.DataFrame(performance_data)

plt.figure(figsize=(14, 8))
sns.barplot(x="train_seq_length", y="final_test_loss", data=performance_df)
plt.title("Final Test Loss for Different Train Lengths")
plt.yscale('log')
plt.xlabel("Train Sequence Length")
plt.ylabel("Final Test Loss (Log Scale)")
plt.show()




# Print performance data for inspection
for data in performance_data:
    print(f"Train Seq Length {data['train_seq_length']}:")
    print(f"  Final Train Loss: {data['final_train_loss']:.3e}")
    print(f"  Final Test Loss: {data['final_test_loss']:.3e}")

# Save performance data to a file if needed
import json
with open("performance_data.json", "w") as f:
    json.dump(performance_data, f)
# Out:
# Train Seq Length 30, Extrapolation Length 90, Epoch 10, Train Loss: 3.617e-01, Test Loss: 1.627e-01, Extrapolation Loss: 6.581e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 20, Train Loss: 3.211e-01, Test Loss: 1.442e-01, Extrapolation Loss: 6.084e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 30, Train Loss: 2.684e-01, Test Loss: 1.184e-01, Extrapolation Loss: 5.157e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 40, Train Loss: 1.995e-01, Test Loss: 8.376e-02, Extrapolation Loss: 3.782e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 50, Train Loss: 1.199e-01, Test Loss: 4.532e-02, Extrapolation Loss: 2.502e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 60, Train Loss: 5.274e-02, Test Loss: 1.822e-02, Extrapolation Loss: 2.722e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 70, Train Loss: 2.580e-02, Test Loss: 1.320e-02, Extrapolation Loss: 4.212e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 80, Train Loss: 2.353e-02, Test Loss: 1.229e-02, Extrapolation Loss: 3.474e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 90, Train Loss: 1.927e-02, Test Loss: 9.534e-03, Extrapolation Loss: 1.841e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 100, Train Loss: 1.569e-02, Test Loss: 8.176e-03, Extrapolation Loss: 9.882e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 110, Train Loss: 1.317e-02, Test Loss: 6.787e-03, Extrapolation Loss: 6.362e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 120, Train Loss: 1.073e-02, Test Loss: 5.538e-03, Extrapolation Loss: 4.357e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 130, Train Loss: 8.578e-03, Test Loss: 4.431e-03, Extrapolation Loss: 2.729e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 140, Train Loss: 6.672e-03, Test Loss: 3.430e-03, Extrapolation Loss: 1.664e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 150, Train Loss: 5.029e-03, Test Loss: 2.571e-03, Extrapolation Loss: 1.314e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 160, Train Loss: 3.685e-03, Test Loss: 1.864e-03, Extrapolation Loss: 1.325e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 170, Train Loss: 2.652e-03, Test Loss: 1.323e-03, Extrapolation Loss: 1.458e-04
# Train Seq Length 30, Extrapolation Length 90:
#   Final Train Loss: 2.565e-03
#   Final Test Loss: 1.277e-03
#   Final Extrapolation Loss: 1.472e-04

# %% [markdown]
# # Experimental Loop - (PI-){NN, KAN, KASSM}

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import json

def oscillator(d, w0, t):
    """Defines the analytical solution to the 1D underdamped harmonic oscillator problem."""
    assert d < w0
    d, w0 = torch.Tensor([d]), torch.Tensor([w0])
    w = torch.sqrt(w0**2 - d**2)
    phi = torch.arctan(-d/w)
    A = 1/(2*torch.cos(phi))
    cos = torch.cos(phi + w*t)
    exp = torch.exp(-d*t)
    x = exp * 2 * A * cos
    return x

def generate_oscillator_data(seq_length, num_sequences, d, w0):
    t = torch.linspace(0, seq_length / 100, seq_length)
    data = oscillator(d, w0, t).unsqueeze(-1)
    sequences = data.repeat(num_sequences, 1, 1)
    times = t.repeat(num_sequences, 1, 1)
    return sequences, times


def train(config):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    performance_data = []

    for train_seq_length in config['train_seq_lengths']:
        extrapolation_length = config['total_seq_length'] - train_seq_length
        
        model = StateSpaceModel(config['state_dim'], config['input_dim'], config['output_dim'], config['kan_layers']).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=config['learning_rate'])
        criterion = nn.MSELoss()
        
        train_data, train_times = generate_oscillator_data(config['total_seq_length'], config['num_sequences'], config['d'], config['w0'])
        train_data, train_times = train_data.to(device), train_times.to(device)
        
        train_losses = []
        test_losses = []
        patience_counter = 0
        
        epoch = 0
        while patience_counter < config['patience']:
            model.train()
            optimizer.zero_grad()
            
            state = train_data[:, :train_seq_length-1, :]
            input = train_data[:, 1:train_seq_length, :]
            observation_target = train_data[:, 1:train_seq_length, :]
            
            state = state.reshape(-1, config['state_dim'])
            input = input.reshape(-1, config['input_dim'])
            observation_target = observation_target.reshape(-1, config['output_dim'])
            
            next_state, observation = model(state, input)
            loss = criterion(next_state, state) + criterion(observation, observation_target)
            
            loss.backward()
            optimizer.step()
            
            train_losses.append(loss.item())

            if len(train_losses) > config['n_pts']:
                recent_losses = train_losses[-config['n_pts']:]
                std_recent_losses = np.std(recent_losses)
                if std_recent_losses < config['convergence_std_threshold']:
                    patience_counter += 1
                else:
                    patience_counter = 0
            else:
                patience_counter = 0
            
            model.eval()
            with torch.no_grad():
                test_state = train_data[:, :train_seq_length-1, :]
                test_input = train_data[:, 1:train_seq_length, :]
                
                test_state = test_state.reshape(-1, config['state_dim'])
                test_input = test_input.reshape(-1, config['input_dim'])
                
                _, test_observation = model(test_state, test_input)
                
                extrap_state = train_data[:, train_seq_length-1:-1, :]
                extrap_input = train_data[:, train_seq_length:, :]
                extrap_target = train_data[:, train_seq_length:, :]
                
                extrap_state = extrap_state.reshape(-1, config['state_dim'])
                extrap_input = extrap_input.reshape(-1, config['input_dim'])
                extrap_target = extrap_target.reshape(-1, config['output_dim'])
                
                _, extrap_observation = model(extrap_state, extrap_input)
                
                test_loss = criterion(test_observation, train_data[:, 1:train_seq_length, :].reshape(-1, config['output_dim']))
                extrapolation_loss = criterion(extrap_observation, extrap_target)
                test_losses.append((test_loss.item(), extrapolation_loss.item()))

            if (epoch + 1) % config['log_interval'] == 0:
                print(f"Train Seq Length {train_seq_length}, Extrapolation Length {extrapolation_length}, Epoch {epoch+1}, Train Loss: {loss.item():.3e}, Test Loss: {test_loss.item():.3e}, Extrapolation Loss: {extrapolation_loss.item():.3e}")
            
            epoch += 1
        
        performance_data.append({
            "train_seq_length": train_seq_length,
            "extrapolation_length": extrapolation_length,
            "final_train_loss": train_losses[-1],
            "final_test_loss": test_losses[-1][0],
            "final_extrapolation_loss": test_losses[-1][1]
        })
        
        train_losses = np.array(train_losses)
        test_losses = np.array(test_losses)
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(test_losses[:, 0], label="Test Loss")
        plt.plot(test_losses[:, 1], label="Extrapolation Loss")
        plt.yscale('log')
        plt.title(f"Loss Curves for Train Seq Length {train_seq_length}, Extrapolation Length {extrapolation_length}")
        plt.xlabel("Epoch")
        plt.ylabel("Loss (Log Scale)")
        plt.legend()
        plt.show()
        
        exemplar_index = 0
        exemplar_state = train_data[exemplar_index, :train_seq_length-1, :].squeeze().cpu().numpy()
        exemplar_input = train_data[exemplar_index, 1:train_seq_length, :].squeeze().cpu().numpy()
        exemplar_target = train_data[exemplar_index, 1:train_seq_length, :].squeeze().cpu().numpy()
        exemplar_extrapolation = train_data[exemplar_index, train_seq_length:, :].squeeze().cpu().numpy()

        model.eval()
        with torch.no_grad():
            extrap_state = train_data[exemplar_index, train_seq_length-1:-1, :]
            extrap_input = train_data[exemplar_index, train_seq_length:, :]
            
            extrap_state = extrap_state.reshape(-1, config['state_dim'])
            extrap_input = extrap_input.reshape(-1, config['input_dim'])
            
            _, extrap_prediction = model(extrap_state, extrap_input)
            extrap_prediction = extrap_prediction.cpu().numpy().reshape(-1)

        plt.figure(figsize=(12, 6))
        plt.plot(range(train_seq_length - 1), exemplar_state, label="State (Training)", color='blue')
        plt.plot(range(1, train_seq_length), exemplar_input, label="Input (Training)", color='green')
        plt.plot(range(1, train_seq_length), exemplar_target, label="Observation Target (Training)", color='red')
        plt.plot(range(train_seq_length, config['total_seq_length']), exemplar_extrapolation, label="Extrapolation Target", color='orange')
        plt.plot(range(train_seq_length, config['total_seq_length']), extrap_prediction, label="Extrapolation Prediction", color='purple', linestyle='--')
        plt.title(f"Exemplar Training Data for Train Seq Length {train_seq_length}, Extrapolation Length {extrapolation_length}")
        plt.xlabel("Time Step")
        plt.ylabel("Value")
        plt.legend()
        plt.show()
    
    performance_df = pd.DataFrame(performance_data)

    plt.figure(figsize=(14, 8))
    sns.barplot(x="train_seq_length", y="final_train_loss", hue="extrapolation_length", data=performance_df)
    plt.title("Final Train Loss for Different Train and Extrapolation Lengths")
    plt.yscale('log')
    plt.xlabel("Train Sequence Length")
    plt.ylabel("Final Train Loss (Log Scale)")
    plt.legend(title="Extrapolation Length")
    plt.show()

    plt.figure(figsize=(14, 8))
    sns.barplot(x="train_seq_length", y="final_extrapolation_loss", hue="extrapolation_length", data=performance_df)
    plt.title("Final Extrapolation Loss for Different Train and Extrapolation Lengths")
    plt.yscale('log')
    plt.xlabel("Train Sequence Length")
    plt.ylabel("Final Extrapolation Loss (Log Scale)")
    plt.legend(title="Extrapolation Length")
    plt.show()

    for data in performance_data:
        print(f"Train Seq Length {data['train_seq_length']}, Extrapolation Length {data['extrapolation_length']}:")
        print(f"  Final Train Loss: {data['final_train_loss']:.3e}")
        print(f"  Final Test Loss: {data['final_test_loss']:.3e}")
        print(f"  Final Extrapolation Loss: {data['final_extrapolation_loss']:.3e}")

    with open(config['performance_data_file'], "w") as f:
        json.dump(performance_data, f)

config = {
    'state_dim': 1,
    'input_dim': 1,
    'output_dim': 1,
    'kan_layers': [16, 16],
    'batch_size': 10,
    'num_sequences': 10,
    'total_seq_length': 120,
    'train_seq_lengths': [10, 15, 30],
    'convergence_std_threshold': 1e-6,
    'patience': 13,
    'n_pts': 100,
    'd': 4,
    'w0': 40,
    'learning_rate': 1e-3,
    'log_interval': 10,
    'performance_data_file': "performance_data.json"
}

train(config)
# Out:
# Train Seq Length 10, Extrapolation Length 110, Epoch 10, Train Loss: 7.534e-01, Test Loss: 3.332e-01, Extrapolation Loss: 2.338e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 20, Train Loss: 6.623e-01, Test Loss: 2.996e-01, Extrapolation Loss: 2.280e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 30, Train Loss: 5.545e-01, Test Loss: 2.541e-01, Extrapolation Loss: 2.231e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 40, Train Loss: 4.222e-01, Test Loss: 1.922e-01, Extrapolation Loss: 2.285e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 50, Train Loss: 2.702e-01, Test Loss: 1.175e-01, Extrapolation Loss: 2.774e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 60, Train Loss: 1.261e-01, Test Loss: 4.749e-02, Extrapolation Loss: 4.427e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 70, Train Loss: 3.606e-02, Test Loss: 9.687e-03, Extrapolation Loss: 7.746e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 80, Train Loss: 1.614e-02, Test Loss: 6.629e-03, Extrapolation Loss: 1.071e-01
# Train Seq Length 10, Extrapolation Length 110, Epoch 90, Train Loss: 1.541e-02, Test Loss: 6.100e-03, Extrapolation Loss: 1.068e-01
# Train Seq Length 10, Extrapolation Length 110, Epoch 100, Train Loss: 1.003e-02, Test Loss: 3.510e-03, Extrapolation Loss: 9.339e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 110, Train Loss: 7.645e-03, Test Loss: 2.863e-03, Extrapolation Loss: 8.447e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 120, Train Loss: 6.413e-03, Test Loss: 2.249e-03, Extrapolation Loss: 8.202e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 130, Train Loss: 5.316e-03, Test Loss: 1.729e-03, Extrapolation Loss: 8.212e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 140, Train Loss: 4.513e-03, Test Loss: 1.386e-03, Extrapolation Loss: 8.055e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 150, Train Loss: 3.851e-03, Test Loss: 1.105e-03, Extrapolation Loss: 7.707e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 160, Train Loss: 3.299e-03, Test Loss: 8.998e-04, Extrapolation Loss: 7.389e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 170, Train Loss: 2.842e-03, Test Loss: 7.491e-04, Extrapolation Loss: 7.170e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 180, Train Loss: 2.464e-03, Test Loss: 6.416e-04, Extrapolation Loss: 6.989e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 190, Train Loss: 2.151e-03, Test Loss: 5.678e-04, Extrapolation Loss: 6.812e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 200, Train Loss: 1.893e-03, Test Loss: 5.185e-04, Extrapolation Loss: 6.653e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 210, Train Loss: 1.679e-03, Test Loss: 4.864e-04, Extrapolation Loss: 6.525e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 220, Train Loss: 1.501e-03, Test Loss: 4.653e-04, Extrapolation Loss: 6.425e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 230, Train Loss: 1.351e-03, Test Loss: 4.505e-04, Extrapolation Loss: 6.344e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 240, Train Loss: 1.224e-03, Test Loss: 4.391e-04, Extrapolation Loss: 6.280e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 250, Train Loss: 1.116e-03, Test Loss: 4.292e-04, Extrapolation Loss: 6.232e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 260, Train Loss: 1.024e-03, Test Loss: 4.200e-04, Extrapolation Loss: 6.195e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 270, Train Loss: 9.449e-04, Test Loss: 4.110e-04, Extrapolation Loss: 6.165e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 280, Train Loss: 8.779e-04, Test Loss: 4.021e-04, Extrapolation Loss: 6.139e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 290, Train Loss: 8.206e-04, Test Loss: 3.934e-04, Extrapolation Loss: 6.115e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 300, Train Loss: 7.716e-04, Test Loss: 3.847e-04, Extrapolation Loss: 6.092e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 310, Train Loss: 7.294e-04, Test Loss: 3.760e-04, Extrapolation Loss: 6.070e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 320, Train Loss: 6.929e-04, Test Loss: 3.672e-04, Extrapolation Loss: 6.048e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 330, Train Loss: 6.608e-04, Test Loss: 3.584e-04, Extrapolation Loss: 6.026e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 340, Train Loss: 6.325e-04, Test Loss: 3.495e-04, Extrapolation Loss: 6.004e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 350, Train Loss: 6.069e-04, Test Loss: 3.405e-04, Extrapolation Loss: 5.983e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 360, Train Loss: 5.836e-04, Test Loss: 3.312e-04, Extrapolation Loss: 5.963e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 370, Train Loss: 5.620e-04, Test Loss: 3.217e-04, Extrapolation Loss: 5.943e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 380, Train Loss: 5.416e-04, Test Loss: 3.120e-04, Extrapolation Loss: 5.925e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 390, Train Loss: 5.220e-04, Test Loss: 3.018e-04, Extrapolation Loss: 5.907e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 400, Train Loss: 5.030e-04, Test Loss: 2.913e-04, Extrapolation Loss: 5.890e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 410, Train Loss: 4.842e-04, Test Loss: 2.803e-04, Extrapolation Loss: 5.875e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 420, Train Loss: 4.655e-04, Test Loss: 2.688e-04, Extrapolation Loss: 5.861e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 430, Train Loss: 4.466e-04, Test Loss: 2.566e-04, Extrapolation Loss: 5.848e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 440, Train Loss: 4.274e-04, Test Loss: 2.438e-04, Extrapolation Loss: 5.837e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 450, Train Loss: 4.077e-04, Test Loss: 2.302e-04, Extrapolation Loss: 5.828e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 460, Train Loss: 3.874e-04, Test Loss: 2.157e-04, Extrapolation Loss: 5.822e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 470, Train Loss: 3.664e-04, Test Loss: 2.004e-04, Extrapolation Loss: 5.819e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 480, Train Loss: 3.447e-04, Test Loss: 1.841e-04, Extrapolation Loss: 5.821e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 490, Train Loss: 3.222e-04, Test Loss: 1.669e-04, Extrapolation Loss: 5.827e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 500, Train Loss: 2.990e-04, Test Loss: 1.490e-04, Extrapolation Loss: 5.840e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 510, Train Loss: 2.754e-04, Test Loss: 1.304e-04, Extrapolation Loss: 5.861e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 520, Train Loss: 2.517e-04, Test Loss: 1.117e-04, Extrapolation Loss: 5.890e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 530, Train Loss: 2.284e-04, Test Loss: 9.335e-05, Extrapolation Loss: 5.928e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 540, Train Loss: 2.062e-04, Test Loss: 7.601e-05, Extrapolation Loss: 5.976e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 550, Train Loss: 1.857e-04, Test Loss: 6.044e-05, Extrapolation Loss: 6.033e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 560, Train Loss: 1.678e-04, Test Loss: 4.733e-05, Extrapolation Loss: 6.095e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 570, Train Loss: 1.529e-04, Test Loss: 3.707e-05, Extrapolation Loss: 6.161e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 580, Train Loss: 1.409e-04, Test Loss: 2.969e-05, Extrapolation Loss: 6.225e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 590, Train Loss: 1.316e-04, Test Loss: 2.478e-05, Extrapolation Loss: 6.285e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 600, Train Loss: 1.243e-04, Test Loss: 2.169e-05, Extrapolation Loss: 6.337e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 610, Train Loss: 1.183e-04, Test Loss: 1.975e-05, Extrapolation Loss: 6.380e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 620, Train Loss: 1.131e-04, Test Loss: 1.844e-05, Extrapolation Loss: 6.416e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 630, Train Loss: 1.083e-04, Test Loss: 1.742e-05, Extrapolation Loss: 6.446e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 640, Train Loss: 1.037e-04, Test Loss: 1.654e-05, Extrapolation Loss: 6.471e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 650, Train Loss: 9.938e-05, Test Loss: 1.572e-05, Extrapolation Loss: 6.493e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 660, Train Loss: 9.518e-05, Test Loss: 1.496e-05, Extrapolation Loss: 6.513e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 670, Train Loss: 9.112e-05, Test Loss: 1.423e-05, Extrapolation Loss: 6.531e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 680, Train Loss: 8.721e-05, Test Loss: 1.354e-05, Extrapolation Loss: 6.549e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 690, Train Loss: 8.344e-05, Test Loss: 1.288e-05, Extrapolation Loss: 6.565e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 700, Train Loss: 7.980e-05, Test Loss: 1.226e-05, Extrapolation Loss: 6.582e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 710, Train Loss: 7.629e-05, Test Loss: 1.167e-05, Extrapolation Loss: 6.597e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 720, Train Loss: 7.292e-05, Test Loss: 1.111e-05, Extrapolation Loss: 6.613e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 730, Train Loss: 6.967e-05, Test Loss: 1.058e-05, Extrapolation Loss: 6.628e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 740, Train Loss: 6.655e-05, Test Loss: 1.008e-05, Extrapolation Loss: 6.642e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 750, Train Loss: 6.355e-05, Test Loss: 9.605e-06, Extrapolation Loss: 6.656e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 760, Train Loss: 6.068e-05, Test Loss: 9.152e-06, Extrapolation Loss: 6.670e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 770, Train Loss: 5.791e-05, Test Loss: 8.722e-06, Extrapolation Loss: 6.683e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 780, Train Loss: 5.527e-05, Test Loss: 8.314e-06, Extrapolation Loss: 6.696e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 790, Train Loss: 5.273e-05, Test Loss: 7.926e-06, Extrapolation Loss: 6.709e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 800, Train Loss: 5.030e-05, Test Loss: 7.557e-06, Extrapolation Loss: 6.721e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 810, Train Loss: 4.797e-05, Test Loss: 7.207e-06, Extrapolation Loss: 6.733e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 820, Train Loss: 4.575e-05, Test Loss: 6.874e-06, Extrapolation Loss: 6.744e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 830, Train Loss: 4.362e-05, Test Loss: 6.556e-06, Extrapolation Loss: 6.755e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 840, Train Loss: 4.160e-05, Test Loss: 6.255e-06, Extrapolation Loss: 6.766e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 850, Train Loss: 3.966e-05, Test Loss: 5.967e-06, Extrapolation Loss: 6.777e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 860, Train Loss: 3.782e-05, Test Loss: 5.693e-06, Extrapolation Loss: 6.787e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 870, Train Loss: 3.606e-05, Test Loss: 5.432e-06, Extrapolation Loss: 6.797e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 880, Train Loss: 3.439e-05, Test Loss: 5.182e-06, Extrapolation Loss: 6.807e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 890, Train Loss: 3.280e-05, Test Loss: 4.945e-06, Extrapolation Loss: 6.817e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 900, Train Loss: 3.129e-05, Test Loss: 4.718e-06, Extrapolation Loss: 6.826e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 910, Train Loss: 2.985e-05, Test Loss: 4.501e-06, Extrapolation Loss: 6.835e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 920, Train Loss: 2.849e-05, Test Loss: 4.295e-06, Extrapolation Loss: 6.844e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 930, Train Loss: 2.720e-05, Test Loss: 4.097e-06, Extrapolation Loss: 6.853e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 940, Train Loss: 2.597e-05, Test Loss: 3.908e-06, Extrapolation Loss: 6.861e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 950, Train Loss: 2.481e-05, Test Loss: 3.728e-06, Extrapolation Loss: 6.870e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 960, Train Loss: 2.372e-05, Test Loss: 3.555e-06, Extrapolation Loss: 6.878e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 970, Train Loss: 2.268e-05, Test Loss: 3.390e-06, Extrapolation Loss: 6.886e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 980, Train Loss: 2.170e-05, Test Loss: 3.232e-06, Extrapolation Loss: 6.894e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 990, Train Loss: 2.077e-05, Test Loss: 3.081e-06, Extrapolation Loss: 6.902e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1000, Train Loss: 1.990e-05, Test Loss: 2.937e-06, Extrapolation Loss: 6.909e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1010, Train Loss: 1.907e-05, Test Loss: 2.798e-06, Extrapolation Loss: 6.916e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1020, Train Loss: 1.829e-05, Test Loss: 2.666e-06, Extrapolation Loss: 6.924e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1030, Train Loss: 1.756e-05, Test Loss: 2.539e-06, Extrapolation Loss: 6.931e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1040, Train Loss: 1.687e-05, Test Loss: 2.418e-06, Extrapolation Loss: 6.938e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1050, Train Loss: 1.621e-05, Test Loss: 2.302e-06, Extrapolation Loss: 6.944e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1060, Train Loss: 1.560e-05, Test Loss: 2.191e-06, Extrapolation Loss: 6.951e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1070, Train Loss: 1.502e-05, Test Loss: 2.085e-06, Extrapolation Loss: 6.958e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1080, Train Loss: 1.447e-05, Test Loss: 1.983e-06, Extrapolation Loss: 6.964e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1090, Train Loss: 1.396e-05, Test Loss: 1.886e-06, Extrapolation Loss: 6.970e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1100, Train Loss: 1.348e-05, Test Loss: 1.792e-06, Extrapolation Loss: 6.976e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1110, Train Loss: 1.302e-05, Test Loss: 1.703e-06, Extrapolation Loss: 6.982e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1120, Train Loss: 1.259e-05, Test Loss: 1.618e-06, Extrapolation Loss: 6.988e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1130, Train Loss: 1.219e-05, Test Loss: 1.537e-06, Extrapolation Loss: 6.994e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1140, Train Loss: 1.181e-05, Test Loss: 1.459e-06, Extrapolation Loss: 7.000e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1150, Train Loss: 1.145e-05, Test Loss: 1.384e-06, Extrapolation Loss: 7.005e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1160, Train Loss: 1.111e-05, Test Loss: 1.313e-06, Extrapolation Loss: 7.011e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1170, Train Loss: 1.079e-05, Test Loss: 1.245e-06, Extrapolation Loss: 7.016e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1180, Train Loss: 1.049e-05, Test Loss: 1.180e-06, Extrapolation Loss: 7.021e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1190, Train Loss: 1.020e-05, Test Loss: 1.118e-06, Extrapolation Loss: 7.026e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1200, Train Loss: 9.932e-06, Test Loss: 1.059e-06, Extrapolation Loss: 7.031e-02
# Train Seq Length 10, Extrapolation Length 110, Epoch 1210, Train Loss: 9.676e-06, Test Loss: 1.002e-06, Extrapolation Loss: 7.036e-02
# Train Seq Length 15, Extrapolation Length 105, Epoch 10, Train Loss: 5.589e-01, Test Loss: 2.442e-01, Extrapolation Loss: 1.833e-02
# Train Seq Length 15, Extrapolation Length 105, Epoch 20, Train Loss: 4.920e-01, Test Loss: 2.118e-01, Extrapolation Loss: 1.620e-02
# Train Seq Length 15, Extrapolation Length 105, Epoch 30, Train Loss: 4.085e-01, Test Loss: 1.708e-01, Extrapolation Loss: 1.334e-02
# Train Seq Length 15, Extrapolation Length 105, Epoch 40, Train Loss: 3.031e-01, Test Loss: 1.192e-01, Extrapolation Loss: 9.343e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 50, Train Loss: 1.846e-01, Test Loss: 6.431e-02, Extrapolation Loss: 5.379e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 60, Train Loss: 8.495e-02, Test Loss: 2.562e-02, Extrapolation Loss: 4.752e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 70, Train Loss: 3.970e-02, Test Loss: 1.602e-02, Extrapolation Loss: 9.108e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 80, Train Loss: 3.204e-02, Test Loss: 1.510e-02, Extrapolation Loss: 1.085e-02
# Train Seq Length 15, Extrapolation Length 105, Epoch 90, Train Loss: 2.643e-02, Test Loss: 1.185e-02, Extrapolation Loss: 6.531e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 100, Train Loss: 2.112e-02, Test Loss: 1.018e-02, Extrapolation Loss: 2.959e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 110, Train Loss: 1.781e-02, Test Loss: 8.952e-03, Extrapolation Loss: 1.884e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 120, Train Loss: 1.515e-02, Test Loss: 7.757e-03, Extrapolation Loss: 1.618e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 130, Train Loss: 1.285e-02, Test Loss: 6.739e-03, Extrapolation Loss: 1.269e-03
# Train Seq Length 15, Extrapolation Length 105, Epoch 140, Train Loss: 1.086e-02, Test Loss: 5.793e-03, Extrapolation Loss: 9.005e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 150, Train Loss: 9.106e-03, Test Loss: 4.933e-03, Extrapolation Loss: 6.643e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 160, Train Loss: 7.560e-03, Test Loss: 4.156e-03, Extrapolation Loss: 5.293e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 170, Train Loss: 6.216e-03, Test Loss: 3.463e-03, Extrapolation Loss: 4.647e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 180, Train Loss: 5.067e-03, Test Loss: 2.855e-03, Extrapolation Loss: 4.488e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 190, Train Loss: 4.101e-03, Test Loss: 2.333e-03, Extrapolation Loss: 4.758e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 200, Train Loss: 3.305e-03, Test Loss: 1.896e-03, Extrapolation Loss: 5.353e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 210, Train Loss: 2.663e-03, Test Loss: 1.540e-03, Extrapolation Loss: 6.029e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 220, Train Loss: 2.154e-03, Test Loss: 1.256e-03, Extrapolation Loss: 6.653e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 230, Train Loss: 1.755e-03, Test Loss: 1.032e-03, Extrapolation Loss: 7.088e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 240, Train Loss: 1.443e-03, Test Loss: 8.566e-04, Extrapolation Loss: 7.247e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 250, Train Loss: 1.197e-03, Test Loss: 7.176e-04, Extrapolation Loss: 7.133e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 260, Train Loss: 1.002e-03, Test Loss: 6.058e-04, Extrapolation Loss: 6.776e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 270, Train Loss: 8.448e-04, Test Loss: 5.143e-04, Extrapolation Loss: 6.252e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 280, Train Loss: 7.165e-04, Test Loss: 4.383e-04, Extrapolation Loss: 5.641e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 290, Train Loss: 6.107e-04, Test Loss: 3.744e-04, Extrapolation Loss: 5.013e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 300, Train Loss: 5.230e-04, Test Loss: 3.206e-04, Extrapolation Loss: 4.413e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 310, Train Loss: 4.502e-04, Test Loss: 2.750e-04, Extrapolation Loss: 3.863e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 320, Train Loss: 3.897e-04, Test Loss: 2.366e-04, Extrapolation Loss: 3.371e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 330, Train Loss: 3.395e-04, Test Loss: 2.043e-04, Extrapolation Loss: 2.935e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 340, Train Loss: 2.979e-04, Test Loss: 1.773e-04, Extrapolation Loss: 2.552e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 350, Train Loss: 2.636e-04, Test Loss: 1.548e-04, Extrapolation Loss: 2.217e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 360, Train Loss: 2.351e-04, Test Loss: 1.360e-04, Extrapolation Loss: 1.927e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 370, Train Loss: 2.114e-04, Test Loss: 1.203e-04, Extrapolation Loss: 1.676e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 380, Train Loss: 1.915e-04, Test Loss: 1.071e-04, Extrapolation Loss: 1.462e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 390, Train Loss: 1.746e-04, Test Loss: 9.578e-05, Extrapolation Loss: 1.278e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 400, Train Loss: 1.600e-04, Test Loss: 8.599e-05, Extrapolation Loss: 1.122e-04
# Train Seq Length 15, Extrapolation Length 105, Epoch 410, Train Loss: 1.473e-04, Test Loss: 7.738e-05, Extrapolation Loss: 9.898e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 420, Train Loss: 1.361e-04, Test Loss: 6.972e-05, Extrapolation Loss: 8.766e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 430, Train Loss: 1.260e-04, Test Loss: 6.281e-05, Extrapolation Loss: 7.794e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 440, Train Loss: 1.168e-04, Test Loss: 5.653e-05, Extrapolation Loss: 6.954e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 450, Train Loss: 1.084e-04, Test Loss: 5.079e-05, Extrapolation Loss: 6.221e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 460, Train Loss: 1.007e-04, Test Loss: 4.553e-05, Extrapolation Loss: 5.578e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 470, Train Loss: 9.364e-05, Test Loss: 4.069e-05, Extrapolation Loss: 5.009e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 480, Train Loss: 8.707e-05, Test Loss: 3.625e-05, Extrapolation Loss: 4.503e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 490, Train Loss: 8.099e-05, Test Loss: 3.219e-05, Extrapolation Loss: 4.050e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 500, Train Loss: 7.536e-05, Test Loss: 2.847e-05, Extrapolation Loss: 3.645e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 510, Train Loss: 7.016e-05, Test Loss: 2.510e-05, Extrapolation Loss: 3.280e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 520, Train Loss: 6.536e-05, Test Loss: 2.204e-05, Extrapolation Loss: 2.952e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 530, Train Loss: 6.093e-05, Test Loss: 1.927e-05, Extrapolation Loss: 2.658e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 540, Train Loss: 5.685e-05, Test Loss: 1.680e-05, Extrapolation Loss: 2.393e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 550, Train Loss: 5.310e-05, Test Loss: 1.458e-05, Extrapolation Loss: 2.155e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 560, Train Loss: 4.966e-05, Test Loss: 1.261e-05, Extrapolation Loss: 1.942e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 570, Train Loss: 4.651e-05, Test Loss: 1.088e-05, Extrapolation Loss: 1.752e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 580, Train Loss: 4.362e-05, Test Loss: 9.346e-06, Extrapolation Loss: 1.583e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 590, Train Loss: 4.098e-05, Test Loss: 8.008e-06, Extrapolation Loss: 1.433e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 600, Train Loss: 3.856e-05, Test Loss: 6.845e-06, Extrapolation Loss: 1.299e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 610, Train Loss: 3.635e-05, Test Loss: 5.838e-06, Extrapolation Loss: 1.182e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 620, Train Loss: 3.433e-05, Test Loss: 4.972e-06, Extrapolation Loss: 1.078e-05
# Train Seq Length 15, Extrapolation Length 105, Epoch 630, Train Loss: 3.248e-05, Test Loss: 4.230e-06, Extrapolation Loss: 9.872e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 640, Train Loss: 3.079e-05, Test Loss: 3.597e-06, Extrapolation Loss: 9.074e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 650, Train Loss: 2.923e-05, Test Loss: 3.061e-06, Extrapolation Loss: 8.376e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 660, Train Loss: 2.779e-05, Test Loss: 2.609e-06, Extrapolation Loss: 7.767e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 670, Train Loss: 2.647e-05, Test Loss: 2.228e-06, Extrapolation Loss: 7.237e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 680, Train Loss: 2.525e-05, Test Loss: 1.910e-06, Extrapolation Loss: 6.776e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 690, Train Loss: 2.412e-05, Test Loss: 1.645e-06, Extrapolation Loss: 6.375e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 700, Train Loss: 2.306e-05, Test Loss: 1.424e-06, Extrapolation Loss: 6.028e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 710, Train Loss: 2.208e-05, Test Loss: 1.241e-06, Extrapolation Loss: 5.727e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 720, Train Loss: 2.116e-05, Test Loss: 1.090e-06, Extrapolation Loss: 5.466e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 730, Train Loss: 2.030e-05, Test Loss: 9.659e-07, Extrapolation Loss: 5.239e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 740, Train Loss: 1.949e-05, Test Loss: 8.632e-07, Extrapolation Loss: 5.043e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 750, Train Loss: 1.873e-05, Test Loss: 7.785e-07, Extrapolation Loss: 4.874e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 760, Train Loss: 1.801e-05, Test Loss: 7.087e-07, Extrapolation Loss: 4.726e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 770, Train Loss: 1.732e-05, Test Loss: 6.511e-07, Extrapolation Loss: 4.599e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 780, Train Loss: 1.667e-05, Test Loss: 6.032e-07, Extrapolation Loss: 4.488e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 790, Train Loss: 1.606e-05, Test Loss: 5.634e-07, Extrapolation Loss: 4.392e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 800, Train Loss: 1.547e-05, Test Loss: 5.301e-07, Extrapolation Loss: 4.308e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 810, Train Loss: 1.491e-05, Test Loss: 5.019e-07, Extrapolation Loss: 4.235e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 820, Train Loss: 1.437e-05, Test Loss: 4.780e-07, Extrapolation Loss: 4.172e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 830, Train Loss: 1.386e-05, Test Loss: 4.574e-07, Extrapolation Loss: 4.116e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 840, Train Loss: 1.337e-05, Test Loss: 4.395e-07, Extrapolation Loss: 4.068e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 850, Train Loss: 1.289e-05, Test Loss: 4.238e-07, Extrapolation Loss: 4.026e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 860, Train Loss: 1.244e-05, Test Loss: 4.098e-07, Extrapolation Loss: 3.989e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 870, Train Loss: 1.201e-05, Test Loss: 3.972e-07, Extrapolation Loss: 3.957e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 880, Train Loss: 1.159e-05, Test Loss: 3.856e-07, Extrapolation Loss: 3.928e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 890, Train Loss: 1.119e-05, Test Loss: 3.750e-07, Extrapolation Loss: 3.904e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 900, Train Loss: 1.081e-05, Test Loss: 3.651e-07, Extrapolation Loss: 3.882e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 910, Train Loss: 1.044e-05, Test Loss: 3.558e-07, Extrapolation Loss: 3.863e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 920, Train Loss: 1.008e-05, Test Loss: 3.470e-07, Extrapolation Loss: 3.846e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 930, Train Loss: 9.735e-06, Test Loss: 3.386e-07, Extrapolation Loss: 3.831e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 940, Train Loss: 9.403e-06, Test Loss: 3.305e-07, Extrapolation Loss: 3.818e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 950, Train Loss: 9.084e-06, Test Loss: 3.227e-07, Extrapolation Loss: 3.806e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 960, Train Loss: 8.776e-06, Test Loss: 3.152e-07, Extrapolation Loss: 3.796e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 970, Train Loss: 8.479e-06, Test Loss: 3.079e-07, Extrapolation Loss: 3.787e-06
# Train Seq Length 15, Extrapolation Length 105, Epoch 980, Train Loss: 8.192e-06, Test Loss: 3.007e-07, Extrapolation Loss: 3.779e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 10, Train Loss: 3.551e-01, Test Loss: 1.662e-01, Extrapolation Loss: 6.421e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 20, Train Loss: 3.148e-01, Test Loss: 1.450e-01, Extrapolation Loss: 5.674e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 30, Train Loss: 2.615e-01, Test Loss: 1.181e-01, Extrapolation Loss: 4.657e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 40, Train Loss: 1.911e-01, Test Loss: 8.405e-02, Extrapolation Loss: 3.354e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 50, Train Loss: 1.099e-01, Test Loss: 4.696e-02, Extrapolation Loss: 2.087e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 60, Train Loss: 4.367e-02, Test Loss: 2.010e-02, Extrapolation Loss: 1.720e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 70, Train Loss: 2.104e-02, Test Loss: 1.350e-02, Extrapolation Loss: 2.241e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 80, Train Loss: 2.094e-02, Test Loss: 1.259e-02, Extrapolation Loss: 2.007e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 90, Train Loss: 1.583e-02, Test Loss: 9.702e-03, Extrapolation Loss: 1.262e-03
# Train Seq Length 30, Extrapolation Length 90, Epoch 100, Train Loss: 1.273e-02, Test Loss: 8.063e-03, Extrapolation Loss: 8.084e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 110, Train Loss: 1.055e-02, Test Loss: 6.631e-03, Extrapolation Loss: 5.406e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 120, Train Loss: 8.416e-03, Test Loss: 5.332e-03, Extrapolation Loss: 3.919e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 130, Train Loss: 6.715e-03, Test Loss: 4.258e-03, Extrapolation Loss: 2.538e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 140, Train Loss: 5.260e-03, Test Loss: 3.335e-03, Extrapolation Loss: 1.365e-04
# Train Seq Length 30, Extrapolation Length 90, Epoch 150, Train Loss: 4.066e-03, Test Loss: 2.577e-03, Extrapolation Loss: 6.767e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 160, Train Loss: 3.113e-03, Test Loss: 1.970e-03, Extrapolation Loss: 3.806e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 170, Train Loss: 2.373e-03, Test Loss: 1.499e-03, Extrapolation Loss: 3.240e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 180, Train Loss: 1.818e-03, Test Loss: 1.147e-03, Extrapolation Loss: 3.975e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 190, Train Loss: 1.413e-03, Test Loss: 8.892e-04, Extrapolation Loss: 5.141e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 200, Train Loss: 1.122e-03, Test Loss: 7.044e-04, Extrapolation Loss: 6.091e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 210, Train Loss: 9.152e-04, Test Loss: 5.720e-04, Extrapolation Loss: 6.427e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 220, Train Loss: 7.658e-04, Test Loss: 4.759e-04, Extrapolation Loss: 6.176e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 230, Train Loss: 6.553e-04, Test Loss: 4.039e-04, Extrapolation Loss: 5.515e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 240, Train Loss: 5.701e-04, Test Loss: 3.479e-04, Extrapolation Loss: 4.693e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 250, Train Loss: 5.014e-04, Test Loss: 3.022e-04, Extrapolation Loss: 3.893e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 260, Train Loss: 4.439e-04, Test Loss: 2.635e-04, Extrapolation Loss: 3.208e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 270, Train Loss: 3.945e-04, Test Loss: 2.300e-04, Extrapolation Loss: 2.668e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 280, Train Loss: 3.515e-04, Test Loss: 2.008e-04, Extrapolation Loss: 2.257e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 290, Train Loss: 3.141e-04, Test Loss: 1.756e-04, Extrapolation Loss: 1.945e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 300, Train Loss: 2.815e-04, Test Loss: 1.538e-04, Extrapolation Loss: 1.703e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 310, Train Loss: 2.532e-04, Test Loss: 1.352e-04, Extrapolation Loss: 1.506e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 320, Train Loss: 2.287e-04, Test Loss: 1.193e-04, Extrapolation Loss: 1.340e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 330, Train Loss: 2.075e-04, Test Loss: 1.059e-04, Extrapolation Loss: 1.197e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 340, Train Loss: 1.890e-04, Test Loss: 9.453e-05, Extrapolation Loss: 1.073e-05
# Train Seq Length 30, Extrapolation Length 90, Epoch 350, Train Loss: 1.730e-04, Test Loss: 8.495e-05, Extrapolation Loss: 9.657e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 360, Train Loss: 1.591e-04, Test Loss: 7.685e-05, Extrapolation Loss: 8.729e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 370, Train Loss: 1.469e-04, Test Loss: 7.000e-05, Extrapolation Loss: 7.928e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 380, Train Loss: 1.362e-04, Test Loss: 6.416e-05, Extrapolation Loss: 7.234e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 390, Train Loss: 1.267e-04, Test Loss: 5.916e-05, Extrapolation Loss: 6.630e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 400, Train Loss: 1.183e-04, Test Loss: 5.483e-05, Extrapolation Loss: 6.099e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 410, Train Loss: 1.108e-04, Test Loss: 5.106e-05, Extrapolation Loss: 5.628e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 420, Train Loss: 1.039e-04, Test Loss: 4.771e-05, Extrapolation Loss: 5.206e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 430, Train Loss: 9.776e-05, Test Loss: 4.473e-05, Extrapolation Loss: 4.825e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 440, Train Loss: 9.209e-05, Test Loss: 4.202e-05, Extrapolation Loss: 4.479e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 450, Train Loss: 8.687e-05, Test Loss: 3.955e-05, Extrapolation Loss: 4.163e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 460, Train Loss: 8.203e-05, Test Loss: 3.727e-05, Extrapolation Loss: 3.873e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 470, Train Loss: 7.752e-05, Test Loss: 3.514e-05, Extrapolation Loss: 3.605e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 480, Train Loss: 7.331e-05, Test Loss: 3.315e-05, Extrapolation Loss: 3.357e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 490, Train Loss: 6.936e-05, Test Loss: 3.127e-05, Extrapolation Loss: 3.126e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 500, Train Loss: 6.564e-05, Test Loss: 2.949e-05, Extrapolation Loss: 2.912e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 510, Train Loss: 6.212e-05, Test Loss: 2.780e-05, Extrapolation Loss: 2.712e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 520, Train Loss: 5.881e-05, Test Loss: 2.619e-05, Extrapolation Loss: 2.525e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 530, Train Loss: 5.566e-05, Test Loss: 2.466e-05, Extrapolation Loss: 2.350e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 540, Train Loss: 5.269e-05, Test Loss: 2.320e-05, Extrapolation Loss: 2.186e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 550, Train Loss: 4.986e-05, Test Loss: 2.181e-05, Extrapolation Loss: 2.033e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 560, Train Loss: 4.718e-05, Test Loss: 2.048e-05, Extrapolation Loss: 1.889e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 570, Train Loss: 4.464e-05, Test Loss: 1.922e-05, Extrapolation Loss: 1.755e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 580, Train Loss: 4.222e-05, Test Loss: 1.801e-05, Extrapolation Loss: 1.630e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 590, Train Loss: 3.992e-05, Test Loss: 1.687e-05, Extrapolation Loss: 1.513e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 600, Train Loss: 3.774e-05, Test Loss: 1.579e-05, Extrapolation Loss: 1.403e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 610, Train Loss: 3.567e-05, Test Loss: 1.475e-05, Extrapolation Loss: 1.301e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 620, Train Loss: 3.371e-05, Test Loss: 1.378e-05, Extrapolation Loss: 1.206e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 630, Train Loss: 3.185e-05, Test Loss: 1.285e-05, Extrapolation Loss: 1.118e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 640, Train Loss: 3.008e-05, Test Loss: 1.198e-05, Extrapolation Loss: 1.036e-06
# Train Seq Length 30, Extrapolation Length 90, Epoch 650, Train Loss: 2.840e-05, Test Loss: 1.115e-05, Extrapolation Loss: 9.596e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 660, Train Loss: 2.681e-05, Test Loss: 1.038e-05, Extrapolation Loss: 8.891e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 670, Train Loss: 2.530e-05, Test Loss: 9.645e-06, Extrapolation Loss: 8.239e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 680, Train Loss: 2.388e-05, Test Loss: 8.957e-06, Extrapolation Loss: 7.638e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 690, Train Loss: 2.253e-05, Test Loss: 8.311e-06, Extrapolation Loss: 7.084e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 700, Train Loss: 2.125e-05, Test Loss: 7.705e-06, Extrapolation Loss: 6.575e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 710, Train Loss: 2.004e-05, Test Loss: 7.138e-06, Extrapolation Loss: 6.107e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 720, Train Loss: 1.891e-05, Test Loss: 6.607e-06, Extrapolation Loss: 5.679e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 730, Train Loss: 1.783e-05, Test Loss: 6.112e-06, Extrapolation Loss: 5.288e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 740, Train Loss: 1.681e-05, Test Loss: 5.650e-06, Extrapolation Loss: 4.931e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 750, Train Loss: 1.586e-05, Test Loss: 5.220e-06, Extrapolation Loss: 4.606e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 760, Train Loss: 1.496e-05, Test Loss: 4.820e-06, Extrapolation Loss: 4.311e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 770, Train Loss: 1.411e-05, Test Loss: 4.449e-06, Extrapolation Loss: 4.043e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 780, Train Loss: 1.331e-05, Test Loss: 4.105e-06, Extrapolation Loss: 3.801e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 790, Train Loss: 1.256e-05, Test Loss: 3.786e-06, Extrapolation Loss: 3.583e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 800, Train Loss: 1.185e-05, Test Loss: 3.491e-06, Extrapolation Loss: 3.386e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 810, Train Loss: 1.119e-05, Test Loss: 3.219e-06, Extrapolation Loss: 3.208e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 820, Train Loss: 1.057e-05, Test Loss: 2.968e-06, Extrapolation Loss: 3.049e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 830, Train Loss: 9.986e-06, Test Loss: 2.737e-06, Extrapolation Loss: 2.907e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 840, Train Loss: 9.439e-06, Test Loss: 2.524e-06, Extrapolation Loss: 2.780e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 850, Train Loss: 8.927e-06, Test Loss: 2.328e-06, Extrapolation Loss: 2.666e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 860, Train Loss: 8.447e-06, Test Loss: 2.149e-06, Extrapolation Loss: 2.565e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 870, Train Loss: 7.999e-06, Test Loss: 1.984e-06, Extrapolation Loss: 2.475e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 880, Train Loss: 7.579e-06, Test Loss: 1.833e-06, Extrapolation Loss: 2.395e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 890, Train Loss: 7.187e-06, Test Loss: 1.695e-06, Extrapolation Loss: 2.324e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 900, Train Loss: 6.820e-06, Test Loss: 1.570e-06, Extrapolation Loss: 2.262e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 910, Train Loss: 6.478e-06, Test Loss: 1.455e-06, Extrapolation Loss: 2.206e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 920, Train Loss: 6.158e-06, Test Loss: 1.350e-06, Extrapolation Loss: 2.158e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 930, Train Loss: 5.859e-06, Test Loss: 1.254e-06, Extrapolation Loss: 2.115e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 940, Train Loss: 5.581e-06, Test Loss: 1.168e-06, Extrapolation Loss: 2.077e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 950, Train Loss: 5.321e-06, Test Loss: 1.089e-06, Extrapolation Loss: 2.043e-07
# Train Seq Length 30, Extrapolation Length 90, Epoch 960, Train Loss: 5.079e-06, Test Loss: 1.017e-06, Extrapolation Loss: 2.014e-07
# Train Seq Length 10, Extrapolation Length 110:
#   Final Train Loss: 9.553e-06
#   Final Test Loss: 9.750e-07
#   Final Extrapolation Loss: 7.039e-02
# Train Seq Length 15, Extrapolation Length 105:
#   Final Train Loss: 7.998e-06
#   Final Test Loss: 2.959e-07
#   Final Extrapolation Loss: 3.775e-06
# Train Seq Length 30, Extrapolation Length 90:
#   Final Train Loss: 4.920e-06
#   Final Test Loss: 9.708e-07
#   Final Extrapolation Loss: 1.995e-07
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 205
#     184         json.dump(performance_data, f)
#     186 config = {
#     187     'state_dim': 1,
#     188     'input_dim': 1,
#    (...)
#     202     'performance_data_file': "performance_data.json"
#     203 }
# --> 205 train(config)
#
# Cell In[4], line 184, in train(config)
#     181     print(f"  Final Extrapolation Loss: {data['final_extrapolation_loss']:.3e}")
#     183 with open(config['performance_data_file'], "w") as f:
# --> 184     json.dump(performance_data, f)
#
# NameError: name 'json' is not defined

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import time
import json

def oscillator(d, w0, t):
    """Defines the analytical solution to the 1D underdamped harmonic oscillator problem."""
    assert d < w0
    d, w0 = torch.Tensor([d]), torch.Tensor([w0])
    w = torch.sqrt(w0**2 - d**2)
    phi = torch.arctan(-d/w)
    A = 1/(2*torch.cos(phi))
    cos = torch.cos(phi + w*t)
    exp = torch.exp(-d*t)
    x = exp * 2 * A * cos
    return x

def generate_oscillator_data(seq_length, num_sequences, d, w0, noise_std=0.0):
    t = torch.linspace(0, seq_length / 100, seq_length)
    data = oscillator(d, w0, t).unsqueeze(-1)
    if noise_std > 0:
        noise = noise_std * torch.randn_like(data)
        data += noise
    sequences = data.repeat(num_sequences, 1, 1)
    times = t.repeat(num_sequences, 1, 1)
    return sequences, times

def create_experiment_directory(base_path="experiments"):
    if not os.path.exists(base_path):
        os.makedirs(base_path)
    run_timestamp = str(int(time.time()))
    run_directory = os.path.join(base_path, run_timestamp)
    os.makedirs(run_directory)
    return run_directory

def save_figure(fig, filepath):
    fig.savefig(filepath, bbox_inches='tight')
    plt.close(fig)

def train(config):
    run_directory = create_experiment_directory()
    
    # Save config to the run directory
    with open(os.path.join(run_directory, "config.json"), "w") as config_file:
        json.dump(config, config_file, indent=4)
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    performance_data = []

    for train_seq_length in config['train_seq_lengths']:
        validation_length = (config['total_seq_length'] - train_seq_length) // 2
        test_length = config['total_seq_length'] - train_seq_length - validation_length
        
        model = StateSpaceModel(config['state_dim'], config['input_dim'], config['output_dim'], config['kan_layers']).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=config['learning_rate'])
        criterion = nn.MSELoss()
        
        # # Generate noisy training data
        # train_data, _ = generate_oscillator_data(train_seq_length, config['num_sequences'], config['d'], config['w0'], noise_std=config['noise_std'])
        # train_data = train_data.to(device)

        # Generate validation data (no noise)
        val_data, _ = generate_oscillator_data(validation_length, config['num_sequences'], config['d'], config['w0'])
        val_data = val_data.to(device)

        # Generate test data (no noise)
        test_data, _ = generate_oscillator_data(test_length, config['num_sequences'], config['d'], config['w0'])
        test_data = test_data.to(device)
        
        train_losses = []
        val_losses = []
        
        epoch = 0
        patience_counter = 0
        while patience_counter < config['patience']:
            model.train()
            optimizer.zero_grad()

            # Generate noisy training data
            train_data, _ = generate_oscillator_data(train_seq_length, config['num_sequences'], config['d'], config['w0'], noise_std=config['noise_std'])
            train_data = train_data.to(device)
            
            state = train_data[:, :train_seq_length-1, :]
            input = train_data[:, 1:train_seq_length, :]
            observation_target = train_data[:, 1:train_seq_length, :]
            
            state = state.reshape(-1, config['state_dim'])
            input = input.reshape(-1, config['input_dim'])
            observation_target = observation_target.reshape(-1, config['output_dim'])
            
            next_state, observation = model(state, input)
            loss = criterion(next_state, state) + criterion(observation, observation_target)
            
            loss.backward()
            optimizer.step()
            
            train_losses.append(loss.item())

            if len(train_losses) > config['n_pts']:
                recent_losses = train_losses[-config['n_pts']:]
                std_recent_losses = np.std(recent_losses)
                if std_recent_losses < config['convergence_std_threshold']:
                    patience_counter += 1
                else:
                    patience_counter = 0
            
            model.eval()
            with torch.no_grad():
                val_state = val_data[:, :validation_length-1, :]
                val_input = val_data[:, 1:validation_length, :]
                
                val_state = val_state.reshape(-1, config['state_dim'])
                val_input = val_input.reshape(-1, config['input_dim'])
                
                _, val_observation = model(val_state, val_input)
                val_loss = criterion(val_observation, val_data[:, 1:validation_length, :].reshape(-1, config['output_dim']))
                val_losses.append(val_loss.item())

            if (epoch + 1) % config['log_interval'] == 0:
                print(f"Train Seq Length {train_seq_length}, Validation Length {validation_length}, Epoch {epoch+1}, Train Loss: {loss.item():.3e}, Val Loss: {val_loss.item():.3e}")
            
            epoch += 1
        
        # Generate final test data
        model.eval()
        with torch.no_grad():
            test_state = test_data[:, :test_length-1, :]
            test_input = test_data[:, 1:test_length, :]
            
            test_state = test_state.reshape(-1, config['state_dim'])
            test_input = test_input.reshape(-1, config['input_dim'])
            
            _, test_observation = model(test_state, test_input)
            test_loss = criterion(test_observation, test_data[:, 1:test_length, :].reshape(-1, config['output_dim']))
        
        performance_data.append({
            "train_seq_length": train_seq_length,
            "validation_length": validation_length,
            "test_length": test_length,
            "final_train_loss": train_losses[-1],
            "final_val_loss": val_losses[-1],
            "final_test_loss": test_loss.item()
        })
        
        train_losses = np.array(train_losses)
        val_losses = np.array(val_losses)
        
        fig = plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Validation Loss")
        plt.yscale('log')
        plt.title(f"Loss Curves for Train Seq Length {train_seq_length}, Validation Length {validation_length}")
        plt.xlabel("Epoch")
        plt.ylabel("Loss (Log Scale)")
        plt.legend()
        save_figure(fig, os.path.join(run_directory, f"loss_curves_{train_seq_length}.png"))
    
    performance_df = pd.DataFrame(performance_data)

    fig = plt.figure(figsize=(14, 8))
    sns.barplot(x="train_seq_length", y="final_train_loss", hue="validation_length", data=performance_df)
    plt.title("Final Train Loss for Different Train and Validation Lengths")
    plt.yscale('log')
    plt.xlabel("Train Sequence Length")
    plt.ylabel("Final Train Loss (Log Scale)")
    plt.legend(title="Validation Length")
    save_figure(fig, os.path.join(run_directory, "final_train_loss.png"))

    fig = plt.figure(figsize=(14, 8))
    sns.barplot(x="train_seq_length", y="final_val_loss", hue="validation_length", data=performance_df)
    plt.title("Final Validation Loss for Different Train and Validation Lengths")
    plt.yscale('log')
    plt.xlabel("Train Sequence Length")
    plt.ylabel("Final Validation Loss (Log Scale)")
    plt.legend(title="Validation Length")
    save_figure(fig, os.path.join(run_directory, "final_val_loss.png"))

    fig = plt.figure(figsize=(14, 8))
    sns.barplot(x="train_seq_length", y="final_test_loss", hue="validation_length", data=performance_df)
    plt.title("Final Test Loss for Different Train and Validation Lengths")
    plt.yscale('log')
    plt.xlabel("Train Sequence Length")
    plt.ylabel("Final Test Loss (Log Scale)")
    plt.legend(title="Validation Length")
    save_figure(fig, os.path.join(run_directory, "final_test_loss.png"))

    performance_df.to_csv(os.path.join(run_directory, "performance_data.csv"), index=False)

    with open(os.path.join(run_directory, "performance_data.json"), "w") as f:
        json.dump(performance_data, f)

    # Within the train function, after model evaluation and performance data logging

    # Plot exemplar data for training, validation, and test sets
    exemplar_index = 0

    # Extract data for plotting
    train_example = train_data[exemplar_index, :train_seq_length, :].squeeze().cpu().numpy()
    val_example = val_data[exemplar_index, :validation_length, :].squeeze().cpu().numpy()
    test_example = test_data[exemplar_index, :test_length, :].squeeze().cpu().numpy()

    # Generate time axes for each segment
    train_time = np.linspace(0, train_seq_length / 100, train_seq_length)
    val_time = np.linspace(train_seq_length / 100, (train_seq_length + validation_length) / 100, validation_length)
    test_time = np.linspace((train_seq_length + validation_length) / 100, config['total_seq_length'] / 100, test_length)

    # Combine all sequences and time axes for plotting
    combined_example = np.concatenate((train_example, val_example, test_example), axis=0)
    combined_time = np.concatenate((train_time, val_time, test_time))

    # Model predictions for the entire sequence (training, validation, and test)
    model.eval()
    with torch.no_grad():
        combined_state = torch.cat([train_data[exemplar_index, :train_seq_length-1, :],
                                    val_data[exemplar_index, :validation_length-1, :],
                                    test_data[exemplar_index, :test_length-1, :]], dim=0)
        combined_input = torch.cat([train_data[exemplar_index, 1:train_seq_length, :],
                                    val_data[exemplar_index, 1:validation_length, :],
                                    test_data[exemplar_index, 1:test_length, :]], dim=0)

        combined_state = combined_state.reshape(-1, config['state_dim']).to(device)
        combined_input = combined_input.reshape(-1, config['input_dim']).to(device)
        
        _, combined_prediction = model(combined_state, combined_input)
        combined_prediction = combined_prediction.cpu().numpy().reshape(-1)

    # Adjust combined time axis for predictions (one step ahead)
    combined_time_predictions = np.concatenate((train_time[1:], val_time[1:], test_time[1:]))

    # Plotting the combined data
    fig = plt.figure(figsize=(12, 6))
    plt.plot(combined_time, combined_example, label="True Data", color='blue')
    plt.plot(combined_time_predictions, combined_prediction, label="Model Prediction", color='red', linestyle='--')
    plt.axvline(x=train_seq_length / 100, color='green', linestyle=':', label='End of Training')
    plt.axvline(x=(train_seq_length + validation_length) / 100, color='orange', linestyle=':', label='End of Validation')
    plt.title(f"Training, Validation, and Test Data with Model Prediction")
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.legend()
    save_figure(fig, os.path.join(run_directory, "combined_data_plot.png"))



config = {
    'state_dim': 1,
    'input_dim': 1,
    'output_dim': 1,
    'kan_layers': [16, 16],
    'batch_size': 10,
    'num_sequences': 10,
    'total_seq_length': 120,
    'train_seq_lengths': [10, 15],
    'convergence_std_threshold': 1e-3,
    'patience': 13,
    'n_pts': 100,
    'd': 4,
    'w0': 40,
    'learning_rate': 1e-3,
    'log_interval': 10,
    'noise_std': 0.1  # Standard deviation of noise for training data
}

train(config)
# Out:
# Train Seq Length 10, Validation Length 55, Epoch 10, Train Loss: 7.613e-01, Val Loss: 9.659e-02
# Train Seq Length 10, Validation Length 55, Epoch 20, Train Loss: 4.771e-01, Val Loss: 8.832e-02
# Train Seq Length 10, Validation Length 55, Epoch 30, Train Loss: 5.999e-01, Val Loss: 7.813e-02
# Train Seq Length 10, Validation Length 55, Epoch 40, Train Loss: 3.824e-01, Val Loss: 6.689e-02
# Train Seq Length 10, Validation Length 55, Epoch 50, Train Loss: 2.869e-01, Val Loss: 5.582e-02
# Train Seq Length 10, Validation Length 55, Epoch 60, Train Loss: 1.750e-01, Val Loss: 4.717e-02
# Train Seq Length 10, Validation Length 55, Epoch 70, Train Loss: 4.374e-02, Val Loss: 4.415e-02
# Train Seq Length 10, Validation Length 55, Epoch 80, Train Loss: 3.989e-02, Val Loss: 4.755e-02
# Train Seq Length 10, Validation Length 55, Epoch 90, Train Loss: 2.109e-02, Val Loss: 4.510e-02
# Train Seq Length 10, Validation Length 55, Epoch 100, Train Loss: 1.852e-02, Val Loss: 3.979e-02
# Train Seq Length 10, Validation Length 55, Epoch 110, Train Loss: 2.424e-02, Val Loss: 3.807e-02
# Train Seq Length 10, Validation Length 55, Epoch 120, Train Loss: 1.372e-02, Val Loss: 3.595e-02
# Train Seq Length 10, Validation Length 55, Epoch 130, Train Loss: 1.063e-02, Val Loss: 3.287e-02
# Train Seq Length 10, Validation Length 55, Epoch 140, Train Loss: 7.332e-03, Val Loss: 3.365e-02
# Train Seq Length 10, Validation Length 55, Epoch 150, Train Loss: 1.670e-02, Val Loss: 3.176e-02
# Train Seq Length 10, Validation Length 55, Epoch 160, Train Loss: 1.746e-02, Val Loss: 3.000e-02
# Train Seq Length 10, Validation Length 55, Epoch 170, Train Loss: 9.352e-03, Val Loss: 2.621e-02
# Train Seq Length 10, Validation Length 55, Epoch 180, Train Loss: 5.400e-03, Val Loss: 2.359e-02
# Train Seq Length 10, Validation Length 55, Epoch 190, Train Loss: 1.037e-02, Val Loss: 2.267e-02
# Train Seq Length 10, Validation Length 55, Epoch 200, Train Loss: 7.222e-03, Val Loss: 2.097e-02
# Train Seq Length 10, Validation Length 55, Epoch 210, Train Loss: 3.374e-03, Val Loss: 2.037e-02
# Train Seq Length 10, Validation Length 55, Epoch 220, Train Loss: 4.152e-03, Val Loss: 1.889e-02
# Train Seq Length 10, Validation Length 55, Epoch 230, Train Loss: 2.659e-03, Val Loss: 1.468e-02
# Train Seq Length 10, Validation Length 55, Epoch 240, Train Loss: 5.046e-03, Val Loss: 1.235e-02
# Train Seq Length 10, Validation Length 55, Epoch 250, Train Loss: 5.673e-03, Val Loss: 1.250e-02
# Train Seq Length 10, Validation Length 55, Epoch 260, Train Loss: 1.133e-02, Val Loss: 1.017e-02
# Train Seq Length 10, Validation Length 55, Epoch 270, Train Loss: 3.809e-03, Val Loss: 8.669e-03
# Train Seq Length 10, Validation Length 55, Epoch 280, Train Loss: 5.256e-04, Val Loss: 7.689e-03
# Train Seq Length 10, Validation Length 55, Epoch 290, Train Loss: 8.783e-04, Val Loss: 6.818e-03
# Train Seq Length 10, Validation Length 55, Epoch 300, Train Loss: 2.289e-03, Val Loss: 6.651e-03
# Train Seq Length 10, Validation Length 55, Epoch 310, Train Loss: 7.827e-04, Val Loss: 5.934e-03
# Train Seq Length 10, Validation Length 55, Epoch 320, Train Loss: 3.350e-03, Val Loss: 3.951e-03
# Train Seq Length 10, Validation Length 55, Epoch 330, Train Loss: 2.730e-03, Val Loss: 4.400e-03
# Train Seq Length 10, Validation Length 55, Epoch 340, Train Loss: 1.505e-03, Val Loss: 3.455e-03
# Train Seq Length 10, Validation Length 55, Epoch 350, Train Loss: 6.796e-04, Val Loss: 2.577e-03
# Train Seq Length 10, Validation Length 55, Epoch 360, Train Loss: 3.912e-03, Val Loss: 2.277e-03
# Train Seq Length 10, Validation Length 55, Epoch 370, Train Loss: 1.576e-03, Val Loss: 2.199e-03
# Train Seq Length 10, Validation Length 55, Epoch 380, Train Loss: 3.182e-04, Val Loss: 1.920e-03
# Train Seq Length 10, Validation Length 55, Epoch 390, Train Loss: 4.984e-04, Val Loss: 1.782e-03
# Train Seq Length 10, Validation Length 55, Epoch 400, Train Loss: 3.638e-04, Val Loss: 1.697e-03
# Train Seq Length 10, Validation Length 55, Epoch 410, Train Loss: 2.674e-04, Val Loss: 1.587e-03
# Train Seq Length 10, Validation Length 55, Epoch 420, Train Loss: 5.832e-04, Val Loss: 1.576e-03
# Train Seq Length 10, Validation Length 55, Epoch 430, Train Loss: 5.613e-04, Val Loss: 1.073e-03
# Train Seq Length 10, Validation Length 55, Epoch 440, Train Loss: 1.955e-04, Val Loss: 1.408e-03
# Train Seq Length 15, Validation Length 52, Epoch 10, Train Loss: 6.120e-01, Val Loss: 1.131e-01
# Train Seq Length 15, Validation Length 52, Epoch 20, Train Loss: 5.326e-01, Val Loss: 1.008e-01
# Train Seq Length 15, Validation Length 52, Epoch 30, Train Loss: 4.412e-01, Val Loss: 8.647e-02
# Train Seq Length 15, Validation Length 52, Epoch 40, Train Loss: 2.702e-01, Val Loss: 6.757e-02
# Train Seq Length 15, Validation Length 52, Epoch 50, Train Loss: 1.872e-01, Val Loss: 4.440e-02
# Train Seq Length 15, Validation Length 52, Epoch 60, Train Loss: 1.450e-01, Val Loss: 2.205e-02
# Train Seq Length 15, Validation Length 52, Epoch 70, Train Loss: 6.146e-02, Val Loss: 1.053e-02
# Train Seq Length 15, Validation Length 52, Epoch 80, Train Loss: 4.194e-02, Val Loss: 1.207e-02
# Train Seq Length 15, Validation Length 52, Epoch 90, Train Loss: 3.423e-02, Val Loss: 1.260e-02
# Train Seq Length 15, Validation Length 52, Epoch 100, Train Loss: 3.192e-02, Val Loss: 9.172e-03
# Train Seq Length 15, Validation Length 52, Epoch 110, Train Loss: 2.549e-02, Val Loss: 6.725e-03
# Train Seq Length 15, Validation Length 52, Epoch 120, Train Loss: 1.530e-02, Val Loss: 5.467e-03
# Train Seq Length 15, Validation Length 52, Epoch 130, Train Loss: 2.031e-02, Val Loss: 4.663e-03
# Train Seq Length 15, Validation Length 52, Epoch 140, Train Loss: 1.717e-02, Val Loss: 4.171e-03
# Train Seq Length 15, Validation Length 52, Epoch 150, Train Loss: 1.150e-02, Val Loss: 3.188e-03
# Train Seq Length 15, Validation Length 52, Epoch 160, Train Loss: 1.092e-02, Val Loss: 2.473e-03
# Train Seq Length 15, Validation Length 52, Epoch 170, Train Loss: 5.298e-03, Val Loss: 2.015e-03
# Train Seq Length 15, Validation Length 52, Epoch 180, Train Loss: 5.934e-03, Val Loss: 1.569e-03
# Train Seq Length 15, Validation Length 52, Epoch 190, Train Loss: 6.887e-03, Val Loss: 1.175e-03
# Train Seq Length 15, Validation Length 52, Epoch 200, Train Loss: 4.655e-03, Val Loss: 8.817e-04
# Train Seq Length 15, Validation Length 52, Epoch 210, Train Loss: 3.296e-03, Val Loss: 7.991e-04
# Train Seq Length 15, Validation Length 52, Epoch 220, Train Loss: 1.587e-03, Val Loss: 5.872e-04
# Train Seq Length 15, Validation Length 52, Epoch 230, Train Loss: 1.853e-03, Val Loss: 4.243e-04
# Train Seq Length 15, Validation Length 52, Epoch 240, Train Loss: 1.095e-03, Val Loss: 3.894e-04
# Train Seq Length 15, Validation Length 52, Epoch 250, Train Loss: 7.974e-04, Val Loss: 3.761e-04
# Train Seq Length 15, Validation Length 52, Epoch 260, Train Loss: 9.597e-04, Val Loss: 3.573e-04
# Train Seq Length 15, Validation Length 52, Epoch 270, Train Loss: 7.021e-04, Val Loss: 3.927e-04
# Train Seq Length 15, Validation Length 52, Epoch 280, Train Loss: 5.280e-04, Val Loss: 2.663e-04
# Train Seq Length 15, Validation Length 52, Epoch 290, Train Loss: 4.797e-04, Val Loss: 2.499e-04
# Train Seq Length 15, Validation Length 52, Epoch 300, Train Loss: 5.618e-04, Val Loss: 1.638e-04
# Train Seq Length 15, Validation Length 52, Epoch 310, Train Loss: 2.945e-04, Val Loss: 1.740e-04
# Train Seq Length 15, Validation Length 52, Epoch 320, Train Loss: 1.412e-03, Val Loss: 1.209e-04
# Train Seq Length 15, Validation Length 52, Epoch 330, Train Loss: 3.224e-04, Val Loss: 1.265e-04
# Train Seq Length 15, Validation Length 52, Epoch 340, Train Loss: 1.948e-04, Val Loss: 1.176e-04
